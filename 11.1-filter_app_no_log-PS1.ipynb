# %% [markdown]
# # (11.1) Application of filter with new distance

# %% [markdown]
# In this notebook we use the new objective function $D_{new} = D_{HD}\times D_{euc}$ in combination with the averaging filter designed in notebook 10. The filter width will be chosen so that the autocorrelation function of the artificial experimental lineage is $1/e$.
#
# Let's start by importing the SSA and the experimental data (only to be used to given initial volumes, molecule numbers and exponential growth rates) and processing it as was done in notebook 5:

# %%
include("./SSA_file.jl"); using .SSAmod;
include("./extract_gens.jl"); using .extract;
using DelimitedFiles;

# %%
filelist = readdir("Analysis_MC4100_37C/MC4100_37C/"); # take the file names - each file is for a different lineage.
raw_data = []; # define the raw data array.
for (i,file) in enumerate(sort!(filelist))
    push!(raw_data,readdlm(string("Analysis_MC4100_37C/MC4100_37C/", file), ',', Float64, '\n'))
end

# %%
fluor_all_lins = [raw_data[x][:,4] for x in 1:length(raw_data)]; # non-separated fluor data.
vol_all_lins = [raw_data[x][:,3] for x in 1:length(raw_data)]; # non-separated vol data.

fluor_sep_all_lins = extract_gens(raw_data,4); # the fluor. data for each lineage sep into gens.
vol_sep_all_lins = extract_gens(raw_data,3); # the vol. data for each lineage sep into gens.
times_sep_all_lins = extract_gens(raw_data,1); # the time pt data for each lineage sep into gens.

fpm = readdlm("MN_props.csv")[1];
exp_grs = readdlm("exp_grs_all.csv", ',', Float64, '\n');

num_sep_all_lins = []; # sep into gens.
for i in 1:length(fluor_sep_all_lins)
    push!(num_sep_all_lins,fluor_sep_all_lins[i]./fpm)
end

# un-sep molecule number and concs for each lineage (including 70th gen to be removed) later).
num_all_lins = [fluor_all_lins[x]./fpm for x in 1:length(fluor_all_lins)];
conc_all_lins = [num_all_lins[x]./vol_all_lins[x] for x in 1:length(fluor_all_lins)];

v0_n0_th = []; # 2-d array to storing (1) the initial values of vol (2) molecule #  and (3) theta for each gen in each lin
for x in 1:length(fluor_all_lins) # the lin loop
    v0_n0_th_x = [];
    for y in 1:length(fluor_sep_all_lins[x]) # the gen loop 1 --> 69
        num = fluor_sep_all_lins[x][y][1]./fpm;
        push!(v0_n0_th_x, [vol_sep_all_lins[x][y][1], num, exp_grs[x,y]])
    end
    push!(v0_n0_th, v0_n0_th_x)
end

# %% [markdown]
# ## First attempt at inference from artificial data

# %% [markdown]
# Now let's create the experimental data of which we wish to infer the parameters of. We again introduce the lineage function created in notebook 5. We set $\alpha_0 = 5.0$, $\alpha_1 = 0.3$, $\beta_0 = 1.0$ and $\beta_1 = 0.5$:

# %%
true_par = [5.0,0.3,1.0,0.5];

# %%
lineage_data = num_sep_all_lins[1]; # take the data for the first lineage, this gives the data form for Single_lin.
lin_ic = v0_n0_th[1]; # pre-set params for lineage 1.

function Single_lin(lin_data::Array{Array{Float64,1},1}, inf_par::Array{Float64,1}, ics::Array{Any,1}) # arguments are wrt each lineage.
    SSA_data_c = [];
    for (i,gen) in enumerate(lin_data)
        ssa = SSA_deg_zero(1, inf_par, ics[i], length(gen)); # for each gen run the SSA with correct ics.
        push!(SSA_data_c, ssa[2][:]);
    end
    return convert(Array{Array{Float64,1},1},SSA_data_c) # return 
end
# Out:
# Single_lin (generic function with 1 method)

# %% [markdown]
# We take the initial conditions on molecule numbers and volume from lineage 1 of the Tanouchi data, as well as the fluorescence per molecule and exponenital growth rate in each generation.

# %%
expt_ssa_conc = Single_lin(lineage_data, true_par, v0_n0_th[1]);

# %% [markdown]
# Let's plot this data:

# %%
using GpABC, LambertW, Distances, Plots, Distributions, LaTeXStrings, StatsBase, Statistics, LinearAlgebra; pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
PyPlot.plot(range(1,length(vcat(expt_ssa_conc...)[:]),step=1),vcat(expt_ssa_conc...)[:]);
PyPlot.ylabel(L"c_{true}(t)"); PyPlot.xlabel(L"t"); PyPlot.xlim([1,length(vcat(expt_ssa_conc...)[:])]);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Plot the histogram (appropriately chosen x axis) and store the bin values as from the PDF.

# %%
fig, ax = PyPlot.subplots(1,1);
mod_bins = LinRange(0.0, maximum(vcat(expt_ssa_conc...)[:])*1.5, 100);
true_bin_vals, other_stuff = ax.hist(vcat(expt_ssa_conc...)[:], bins = mod_bins, density = true);
print("\n",sum(true_bin_vals*(maximum(vcat(expt_ssa_conc...)[:])*1.5/100))) # check the sum of bins is 1.

true_bin_vals_form = convert(Array{Float64,2},transpose(true_bin_vals));
# Out:
# 0.9899999999999998
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Now let's look at the autocorrelation function of the lineage.

# %%
using StatsBase;

# %%
expt_ac = autocor(vcat(expt_ssa_conc...)[:], range(0, length(vcat(expt_ssa_conc...)[:])-1, step=1), demean = true);
fig, ax = PyPlot.subplots(1,1, sharex = true);
ax.plot(expt_ac); ax.plot(ones(length(expt_ac)).* exp(-1)); ax.set_xlim(0,20);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Clearly this is not reasonable. Let's choose $n = 4$ and plot the filtered experimental SSA lineage.

# %%
n = 4;

lin_expt = vcat(expt_ssa_conc...); filter_expt = filter_lin(expt_ssa_conc, n)[2]
filter_expt_form = hcat(filter_expt);

fig, axs = PyPlot.subplots(2, 1, sharex = true, tight_layout = true);
axs[2].set_xlabel(L"t"); axs[1].set_ylabel(L"c_{exp}(t)"); axs[2].set_ylabel(L"c_{filter}(t)"); 
axs[1].plot(range(1,length(lin_expt),step=1),lin_expt); axs[2].plot(range(1,length(filter_expt),step=1),filter_expt);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
# function that returns the SSA concentration for lineage specified abvove.
function simulator_function_conc(var_params::Array{Float64,1})
    lin_conc = filter_lin(Single_lin(lineage_data, var_params, lin_ic)[:], n)[2] # choose up-sep form [2]
    return hcat(lin_conc)::Array{Float64,2}
end
# Out:
# simulator_function_conc (generic function with 1 method)

# %% [markdown]
# Create the new distance function that takes in the sample trajectory vector and experimental trajectory as inputs and outputs the product of the hellinger distance and the euclidean distance between the two trajectories.

# %%
function new_distance(samp_traj::Array{Float64,1}, exp_traj::Array{Float64,1})
    euc_dist = euclidean(samp_traj[:], exp_traj[:]); # euclidean distance
    samp_bins = normalize(fit(Histogram, samp_traj[:], mod_bins), mode=:probability).weights;
    exp_bins = normalize(fit(Histogram, exp_traj[:], mod_bins), mode=:probability).weights;
    hell_dist = hellinger(samp_bins, exp_bins); # HD
    
    return euc_dist*hell_dist::Float64 # return the product
end
# Out:
# new_distance (generic function with 1 method)

# %%
thres_cutoff = sum(new_distance(simulator_function_conc(true_par)[:], filter_expt_form[:]) for i in 1:1000)/1000
# Out:
# 66.03432952183275

# %%
@time new_distance(simulator_function_conc(true_par)[:], filter_expt_form[:])
# Out:
#   0.008103 seconds (22.95 k allocations: 2.003 MiB)
# 64.37538191989117

# %%
n_particles = 1000;
threshold_schedule = [500.0, 250.0, 150.0, 100.0, 80.0, 70.0, 65.0];

priors = [Uniform(0, 10.0), Uniform(0.0, 1.8), Uniform(0, 10.0),
          Uniform(0.0, 1.8)];

sim_abcsmc_res_conc_1 = SimulatedABCSMC(filter_expt_form,
    simulator_function_conc,
    priors,
    threshold_schedule,
    n_particles;
    write_progress=true,
    distance_function = new_distance,
    max_iter = convert(Int,5E4))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053"]#,"#E75935","#E84D26","#E84117","#CF3008","#AB2402","#351D17"]
plot(sim_abcsmc_res_conc_1, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 500.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC rejection simulation. Accepted 48/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 97/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 140/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 194/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 239/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 288/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 333/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 387/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 442/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 498/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 546/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 586/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 634/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 686/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 739/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 787/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 842/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 892/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 940/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 993/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC SMC simulation ϵ = 250.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 51/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 100/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 134/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 180/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 226/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 271/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 312/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 364/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 407/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 450/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 485/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 520/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 565/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 621/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 670/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 716/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 762/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 815/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 868/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 922/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 970/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 150.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 47/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 85/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 125/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 173/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 205/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 257/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 309/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 359/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 399/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 447/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 490/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 526/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 564/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 607/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 655/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 703/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 744/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 781/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 824/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 863/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 900/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 954/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 100.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 43/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 81/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 134/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 184/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 238/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 284/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 324/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 374/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 427/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 462/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 509/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 557/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 604/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 641/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 692/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 738/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 788/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 845/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 897/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 937/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 995/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 80.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 29/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 52/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 84/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 112/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 136/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 163/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 192/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 224/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 240/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 267/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 292/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 318/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 353/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 370/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 396/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 421/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 448/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 473/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 494/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 521/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 541/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 565/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 585/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 619/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 642/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 661/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 681/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 702/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 721/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 748/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 770/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 792/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 812/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 838/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 862/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 903/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 937/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 973/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 70.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 25/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 55/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 71/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 96/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 122/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 148/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 168/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 186/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 213/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 244/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 273/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 296/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 323/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 342/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 370/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 389/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 424/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 453/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 475/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 500/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 520/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 551/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 567/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 583/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 618/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 641/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 667/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 687/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 717/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 746/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 771/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 799/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 818/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 843/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 865/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 886/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 916/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 950/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 980/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 65.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 20/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 46/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 66/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 89/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 116/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 144/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 170/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 196/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 218/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 240/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 262/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 280/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 307/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 336/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 366/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 392/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 414/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 435/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 456/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 486/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 514/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 543/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 563/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 590/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 609/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 616/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 641/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 661/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 692/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 714/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 735/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 763/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 782/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 807/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 834/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 865/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 889/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 913/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 940/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 962/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 991/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238

# %%
pars_conc_1 = [median(sim_abcsmc_res_conc_1.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#  8.241086427073727
#  0.8085200496677027
#  0.5233407617205565
#  0.15170630908582114

# %%
true_par
# Out:
# 4-element Array{Float64,1}:
#  5.0
#  0.3
#  1.0
#  0.5

# %% [markdown]
# Print the differences.

# %%
diff = (pars_conc_1 - true_par)
# Out:
# 4-element Array{Float64,1}:
#   3.2410864270737267
#   0.5085200496677027
#  -0.47665923827944345
#  -0.34829369091417883

# %% [markdown]
# Plot an SSA trajectory using the inferred parameters and compare against the experimental SSA.

# %%
single = @time Single_lin(num_sep_all_lins[1], pars_conc_1, v0_n0_th[1]); # do for first gen.
concs_ssa_1 = vcat(single[1:length(single)]...)[:]; expt_c = vcat(expt_ssa_conc...)[:];

fig, axs = PyPlot.subplots(2, 1, sharex = true, tight_layout = true);
axs[2].set_xlabel(L"t"); axs[1].set_ylabel(L"c_{exp}(t)"); axs[2].set_ylabel(L"c_{SSA}(t)"); 
axs[1].plot(range(1,length(expt_c),step=1),expt_c); axs[2].plot(range(1,length(concs_ssa_1),step=1),concs_ssa_1);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
#   0.015953 seconds (45.84 k allocations: 4.263 MiB)

# %% [markdown]
# The inability to infer parameters here seems to arise from the indistinguishability of parameter sets with respect to this objective function of the HD. This is also shown above by the similarity of the behaviour in the concentration trajectories.

# %%
fig, ax = PyPlot.subplots(1, 2, sharey = true);
true_bin_vals_inf, other_stuff = ax[1].hist(concs_ssa_1[:], bins = mod_bins, density = true);
ax[1].set_title("inferred params"); 
true_bin_vals, other_stuff = ax[2].hist(expt_c[:], bins = mod_bins, density = true);
ax[2].set_title("real params");
print("Hellinger distance between these is: ", hellinger(true_bin_vals_inf[:],true_bin_vals[:])) # print the bin values.
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# Hellinger distance between these is: 0.1300734359179609

# %% [markdown]
# ## Run them again!

# %%
n_particles = 1000;
threshold_schedule = [500.0, 250.0, 150.0, 100.0, 80.0, 70.0, 65.0];

priors = [Uniform(0, 10.0), Uniform(0.0, 1.8), Uniform(0, 10.0),
          Uniform(0.0, 1.8)];

sim_abcsmc_res_conc_2 = SimulatedABCSMC(filter_expt_form,
    simulator_function_conc,
    priors,
    threshold_schedule,
    n_particles;
    write_progress=true,
    distance_function = new_distance,
    max_iter = convert(Int,5E4))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053","#E75935","#E84D26","#E84117","#CF3008","#AB2402","#351D17"]
plot(sim_abcsmc_res_conc_2, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 500.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC rejection simulation. Accepted 48/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 101/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 149/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 200/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 262/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 320/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 360/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 423/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 477/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 528/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 575/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 622/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 681/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 722/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 784/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 833/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 887/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 928/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 984/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC SMC simulation ϵ = 250.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 49/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 87/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 142/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 190/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 234/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 275/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 316/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 356/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 406/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 449/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 490/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 535/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 583/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 628/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 659/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 697/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 735/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 783/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 818/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 877/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 920/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 970/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 150.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 59/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 121/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 179/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 236/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 289/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 347/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 396/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 449/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 511/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 548/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 609/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 658/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 724/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 786/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 829/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 883/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 946/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 996/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 100.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 43/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 92/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 137/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 180/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 217/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 267/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 322/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 377/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 417/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 462/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 506/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 547/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 593/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 631/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 679/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 730/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 774/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 825/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 867/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 918/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 968/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 80.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 31/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 55/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 74/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 105/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 127/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 148/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 170/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 192/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 212/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 242/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 260/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 285/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 317/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 345/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 375/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 397/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 425/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 449/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 476/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 506/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 533/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 561/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 594/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 614/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 642/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 657/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 678/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 703/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 727/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 761/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 781/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 804/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 824/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 852/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 872/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 889/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 917/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 942/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 963/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 983/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 70.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 26/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 49/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 79/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 106/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 130/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 153/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 179/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 208/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 233/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 264/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 292/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 313/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 341/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 359/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 385/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 407/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 432/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 449/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 472/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 492/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 520/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 539/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 565/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 590/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 616/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 635/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 657/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 681/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 700/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 733/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 751/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 770/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 796/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 822/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 843/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 870/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 905/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 929/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 952/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 976/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 995/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 65.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 22/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 50/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 71/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 83/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 101/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 124/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 147/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 164/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 185/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 212/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 230/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 247/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 265/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 290/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 307/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 335/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 361/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 381/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 406/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 421/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 448/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 462/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 485/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 507/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 528/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 547/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 567/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 588/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 602/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 613/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 634/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 651/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 672/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 695/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 714/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 733/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 760/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 778/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 812/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 830/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 846/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 870/42000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 890/43000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 908/44000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 926/45000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 941/46000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 965/47000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 986/48000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238

# %%
pars_conc_2 = [median(sim_abcsmc_res_conc_2.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#  6.406738630942437
#  0.37151641743770514
#  0.987812190590269
#  0.1747463643066638

# %%
true_par
# Out:
# 4-element Array{Float64,1}:
#  5.0
#  0.3
#  1.0
#  0.5

# %% [markdown]
# Print the differences.

# %%
diff_2 = (pars_conc_2 - true_par)
# Out:
# 4-element Array{Float64,1}:
#   1.4067386309424368
#   0.07151641743770515
#  -0.012187809409730965
#  -0.3252536356933362

# %%
n_particles = 1000;
threshold_schedule = [500.0, 250.0, 150.0, 100.0, 80.0, 70.0, 65.0];

priors = [Uniform(0, 10.0), Uniform(0.0, 1.8), Uniform(0, 10.0),
          Uniform(0.0, 1.8)];

sim_abcsmc_res_conc_3 = SimulatedABCSMC(filter_expt_form,
    simulator_function_conc,
    priors,
    threshold_schedule,
    n_particles;
    write_progress=true,
    distance_function = new_distance,
    max_iter = convert(Int,5E4))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053","#E75935","#E84D26","#E84117","#CF3008","#AB2402","#351D17"]
plot(sim_abcsmc_res_conc_3, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 500.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC rejection simulation. Accepted 54/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 102/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 152/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 194/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 242/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 304/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 346/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 400/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 446/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 496/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 540/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 578/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 633/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 681/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 726/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 786/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 843/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 904/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 954/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC SMC simulation ϵ = 250.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 39/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 75/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 125/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 166/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 210/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 256/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 301/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 352/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 393/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 435/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 474/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 521/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 582/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 628/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 656/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 704/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 751/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 797/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 841/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 891/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 925/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 973/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 150.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 18/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 35/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 47/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 66/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 83/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 100/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 110/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 125/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 133/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 149/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 168/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 186/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 200/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 213/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 229/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 241/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 251/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 265/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 278/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 300/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 312/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 329/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 342/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 365/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 377/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 394/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 411/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 424/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 438/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 451/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 473/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 491/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 508/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 524/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 539/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 556/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 572/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 587/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 608/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 620/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 637/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 658/42000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 674/43000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 685/44000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 702/45000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 720/46000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 734/47000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 760/48000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 772/49000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 785/50000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Warning: Simulation reached maximum 50000 iterations before finding 1000 particles - will return 785
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:248
# ┌ Info: GpABC SMC simulation ϵ = 100.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 25/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 52/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 81/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 111/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 141/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 169/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 201/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 225/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 265/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 286/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 323/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 351/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 376/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 408/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 439/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 468/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 504/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 534/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 569/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 609/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 639/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 661/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 686/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 722/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 747/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 775/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 800/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 822/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 853/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 885/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 912/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 939/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 973/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 80.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 27/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 46/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 69/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 90/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 121/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 151/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 175/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 213/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 242/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 269/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 292/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 314/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 343/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 368/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 395/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 424/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 445/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 464/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 492/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 509/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 543/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 572/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 598/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 620/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 646/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 669/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 703/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 729/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 747/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 779/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 812/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 841/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 869/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 898/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 926/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 946/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 976/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 70.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 31/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 61/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 81/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 104/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 140/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 169/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 202/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 233/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 261/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 292/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 325/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 351/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 374/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 400/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 425/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 449/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 479/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 503/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 540/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 564/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 596/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 628/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 662/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 696/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 721/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 748/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 787/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 822/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 855/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 888/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 921/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 944/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 971/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 993/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 65.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 17/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 34/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 51/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 64/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 78/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 92/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 107/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 128/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 147/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 171/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 193/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 215/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 243/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 256/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 272/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 285/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 304/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 324/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 348/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 367/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 388/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 407/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 422/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 437/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 450/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 471/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 490/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 506/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 528/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 545/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 569/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 584/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 600/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 622/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 647/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 669/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 679/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 693/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 714/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 732/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 752/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 774/42000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 796/43000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 817/44000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 842/45000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 857/46000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 875/47000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 889/48000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 904/49000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 925/50000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Warning: Simulation reached maximum 50000 iterations before finding 1000 particles - will return 925
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:248

# %%
pars_conc_3 = [median(sim_abcsmc_res_conc_3.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#  7.614209203410708
#  0.5200621877426711
#  0.520189999845482
#  0.496955509021759

# %%
true_par
# Out:
# 4-element Array{Float64,1}:
#  5.0
#  0.3
#  1.0
#  0.5

# %% [markdown]
# Print the differences.

# %%
diff_3 = (pars_conc_3 - true_par)
# Out:
# 4-element Array{Float64,1}:
#   2.6142092034107076
#   0.2200621877426711
#  -0.479810000154518
#  -0.003044490978240999

# %% [markdown]
# ## Summary of results

# %% [markdown]
# The model that we are attempting to infer the parameter for is:
# $$\varnothing \xrightarrow{a_1(t)}m\, P\xrightarrow{d}\varnothing,$$
# where $a_1(t) = \alpha_0 V(t)^{\alpha_1}$ and $m$ is a random number drawn from a geometric distribution with time-dependent mean burst size $b(t) = \beta_0 V(t)^{\beta_1}$ and degradation rate $d = 0$. The volume of the system grows according to exponential growth law: $V(t) = V_0 e^{\theta t}$. Later on in this sheet we also go onto assess the minimum threshold for the SMC-ABC data.

# %% [markdown]
# Let's see the inferred medians of the posterior distributions in some tables.

# %%
using DataFrames;

# %%
par_conc = convert(Array{Float64,2},transpose([true_par pars_conc_1 pars_conc_2 pars_conc_3]));
df_conc = DataFrame(alpha_0 = par_conc[:,1], alpha_1 = par_conc[:,2], beta_0 = par_conc[:,3], beta_1 = par_conc[:,4]);

# %%
df_conc
# Out:
# 4×4 DataFrame
# │ Row │ alpha_0 │ alpha_1  │ beta_0   │ beta_1   │
# │     │ Float64 │ Float64  │ Float64  │ Float64  │
# ├─────┼─────────┼──────────┼──────────┼──────────┤
# │ 1   │ 5.0     │ 0.3      │ 1.0      │ 0.5      │
# │ 2   │ 8.24109 │ 0.80852  │ 0.523341 │ 0.151706 │
# │ 3   │ 6.40674 │ 0.371516 │ 0.987812 │ 0.174746 │
# │ 4   │ 7.61421 │ 0.520062 │ 0.52019  │ 0.496956 │
