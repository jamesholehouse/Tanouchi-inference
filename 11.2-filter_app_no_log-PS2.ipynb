# %% [markdown]
# # (11.2) Application of filter with new distance - burst size volume dependence

# %% [markdown]
# In this notebook we use the new objective function $D_{new} = D_{HD}\times D_{euc}$ in combination with the averaging filter designed in notebook 10. The filter width will be chosen so that the autocorrelation function of the artificial experimental lineage is $1/e$.
#
# Let's start by importing the SSA and the experimental data (only to be used to given initial volumes, molecule numbers and exponential growth rates) and processing it as was done in notebook 5:

# %%
include("./SSA_file.jl"); using .SSAmod;
include("./extract_gens.jl"); using .extract;
using DelimitedFiles;

# %%
filelist = readdir("Analysis_MC4100_37C/MC4100_37C/"); # take the file names - each file is for a different lineage.
raw_data = []; # define the raw data array.
for (i,file) in enumerate(sort!(filelist))
    push!(raw_data,readdlm(string("Analysis_MC4100_37C/MC4100_37C/", file), ',', Float64, '\n'))
end

# %%
fluor_all_lins = [raw_data[x][:,4] for x in 1:length(raw_data)]; # non-separated fluor data.
vol_all_lins = [raw_data[x][:,3] for x in 1:length(raw_data)]; # non-separated vol data.

fluor_sep_all_lins = extract_gens(raw_data,4); # the fluor. data for each lineage sep into gens.
vol_sep_all_lins = extract_gens(raw_data,3); # the vol. data for each lineage sep into gens.
times_sep_all_lins = extract_gens(raw_data,1); # the time pt data for each lineage sep into gens.

fpm = readdlm("MN_props.csv")[1];
exp_grs = readdlm("exp_grs_all.csv", ',', Float64, '\n');

num_sep_all_lins = []; # sep into gens.
for i in 1:length(fluor_sep_all_lins)
    push!(num_sep_all_lins,fluor_sep_all_lins[i]./fpm)
end

# un-sep molecule number and concs for each lineage (including 70th gen to be removed) later).
num_all_lins = [fluor_all_lins[x]./fpm for x in 1:length(fluor_all_lins)];
conc_all_lins = [num_all_lins[x]./vol_all_lins[x] for x in 1:length(fluor_all_lins)];

v0_n0_th = []; # 2-d array to storing (1) the initial values of vol (2) molecule #  and (3) theta for each gen in each lin
for x in 1:length(fluor_all_lins) # the lin loop
    v0_n0_th_x = [];
    for y in 1:length(fluor_sep_all_lins[x]) # the gen loop 1 --> 69
        num = fluor_sep_all_lins[x][y][1]./fpm;
        push!(v0_n0_th_x, [vol_sep_all_lins[x][y][1], num, exp_grs[x,y]])
    end
    push!(v0_n0_th, v0_n0_th_x)
end

# %% [markdown]
# ## Second attempt at inference from artificial data

# %% [markdown]
# Now let's create the experimental data of which we wish to infer the parameters of. We again introduce the lineage function created in notebook 5. We set $\alpha_0 = 5.0$, $\alpha_1 = 0.0$, $\beta_0 = 1.0$ and $\beta_1 = 1.0$:

# %%
true_par = [5.0,0.000001,1.0,1.0];

# %%
lineage_data = num_sep_all_lins[1]; # take the data for the first lineage, this gives the data form for Single_lin.
lin_ic = v0_n0_th[1]; # pre-set params for lineage 1.

function Single_lin(lin_data::Array{Array{Float64,1},1}, inf_par::Array{Float64,1}, ics::Array{Any,1}) # arguments are wrt each lineage.
    SSA_data_c = [];
    for (i,gen) in enumerate(lin_data)
        ssa = SSA_deg_zero(1, inf_par, ics[i], length(gen)); # for each gen run the SSA with correct ics.
        push!(SSA_data_c, ssa[2][:]);
    end
    return convert(Array{Array{Float64,1},1},SSA_data_c) # return 
end
# Out:
# Single_lin (generic function with 1 method)

# %% [markdown]
# We take the initial conditions on molecule numbers and volume from lineage 1 of the Tanouchi data, as well as the fluorescence per molecule and exponenital growth rate in each generation.

# %%
expt_ssa_conc = Single_lin(lineage_data, true_par, v0_n0_th[1]);

# %% [markdown]
# Let's plot this data:

# %%
using GpABC, LambertW, Distances, Plots, Distributions, LaTeXStrings, StatsBase, Statistics, LinearAlgebra; pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
PyPlot.plot(range(1,length(vcat(expt_ssa_conc...)[:]),step=1),vcat(expt_ssa_conc...)[:]);
PyPlot.ylabel(L"c_{true}(t)"); PyPlot.xlabel(L"t"); PyPlot.xlim([1,length(vcat(expt_ssa_conc...)[:])]);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Plot the histogram (appropriately chosen x axis) and store the bin values as from the PDF.

# %%
fig, ax = PyPlot.subplots(1,1);
mod_bins = LinRange(0.0, maximum(vcat(expt_ssa_conc...)[:])*1.5, 100);
true_bin_vals, other_stuff = ax.hist(vcat(expt_ssa_conc...)[:], bins = mod_bins, density = true);
print("\n",sum(true_bin_vals*(maximum(vcat(expt_ssa_conc...)[:])*1.5/100))) # check the sum of bins is 1.

true_bin_vals_form = convert(Array{Float64,2},transpose(true_bin_vals));
# Out:
# 0.9900000000000001
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Let's choose $n = 4$ and plot the filtered experimental SSA lineage.

# %%
n = 4;

lin_expt = vcat(expt_ssa_conc...); filter_expt = filter_lin(expt_ssa_conc, n)[2]
filter_expt_form = hcat(filter_expt);

fig, axs = PyPlot.subplots(2, 1, sharex = true, tight_layout = true);
axs[2].set_xlabel(L"t"); axs[1].set_ylabel(L"c_{exp}(t)"); axs[2].set_ylabel(L"c_{filter}(t)"); 
axs[1].plot(range(1,length(lin_expt),step=1),lin_expt); axs[2].plot(range(1,length(filter_expt),step=1),filter_expt);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
# function that returns the SSA concentration for lineage specified abvove.
function simulator_function_conc(var_params::Array{Float64,1})
    lin_conc = filter_lin(Single_lin(lineage_data, var_params, lin_ic)[:], n)[2] # choose up-sep form [2]
    return hcat(lin_conc)::Array{Float64,2}
end
# Out:
# simulator_function_conc (generic function with 1 method)

# %% [markdown]
# Create the new distance function that takes in the sample trajectory vector and experimental trajectory as inputs and outputs the product of the hellinger distance and the euclidean distance between the two trajectories.

# %%
function new_distance(samp_traj::Array{Float64,1}, exp_traj::Array{Float64,1})
    euc_dist = euclidean(samp_traj[:], exp_traj[:]); # euclidean distance
    samp_bins = normalize(fit(Histogram, samp_traj[:], mod_bins), mode=:probability).weights;
    exp_bins = normalize(fit(Histogram, exp_traj[:], mod_bins), mode=:probability).weights;
    hell_dist = hellinger(samp_bins, exp_bins); # HD
    
    return euc_dist*hell_dist::Float64 # return the product
end
# Out:
# new_distance (generic function with 1 method)

# %%
thres_cutoff = sum(new_distance(simulator_function_conc(true_par)[:], filter_expt_form[:]) for i in 1:1000)/1000
# Out:
# 92.65608474157735

# %%
@time new_distance(simulator_function_conc(true_par)[:], filter_expt_form[:])
# Out:
#   0.005908 seconds (18.43 k allocations: 1.590 MiB)
# 104.91720338613638

# %%
n_particles = 1000;
threshold_schedule = [500.0, 250.0, 150.0, 120.0, 110.0, 105.0, 100.0];

priors = [Uniform(0, 10.0), Uniform(0.0, 1.8), Uniform(0, 10.0),
          Uniform(0.0, 1.8)];

sim_abcsmc_res_conc_1 = SimulatedABCSMC(filter_expt_form,
    simulator_function_conc,
    priors,
    threshold_schedule,
    n_particles;
    write_progress=true,
    distance_function = new_distance,
    max_iter = convert(Int,5E4))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053"]#,"#E75935","#E84D26","#E84117","#CF3008","#AB2402","#351D17"]
plot(sim_abcsmc_res_conc_1, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 500.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC rejection simulation. Accepted 43/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 94/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 140/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 196/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 245/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 314/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 363/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 418/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 463/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 510/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 575/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 632/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 697/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 740/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 790/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 840/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 907/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 962/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC SMC simulation ϵ = 250.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 51/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 99/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 138/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 182/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 224/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 258/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 291/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 335/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 372/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 414/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 446/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 483/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 526/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 558/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 616/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 657/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 693/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 737/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 771/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 823/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 865/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 908/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 946/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 987/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 150.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 19/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 33/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 54/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 70/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 90/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 105/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 134/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 154/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 175/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 189/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 211/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 235/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 260/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 281/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 296/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 318/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 333/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 348/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 371/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 391/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 408/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 430/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 454/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 481/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 505/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 521/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 540/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 566/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 587/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 605/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 622/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 638/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 660/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 674/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 699/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 714/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 734/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 760/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 779/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 798/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 818/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 840/42000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 858/43000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 878/44000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 899/45000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 917/46000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 938/47000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 961/48000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 977/49000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 994/50000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Warning: Simulation reached maximum 50000 iterations before finding 1000 particles - will return 994
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:248
# ┌ Info: GpABC SMC simulation ϵ = 120.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 28/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 47/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 70/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 87/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 104/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 128/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 143/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 166/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 189/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 205/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 228/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 243/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 260/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 275/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 297/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 318/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 346/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 370/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 390/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 412/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 429/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 450/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 475/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 493/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 518/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 537/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 566/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 590/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 612/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 633/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 646/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 668/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 682/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 708/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 730/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 759/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 777/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 806/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 833/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 854/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 879/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 891/42000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 910/43000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 927/44000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 956/45000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 975/46000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 999/47000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 110.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 47/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 91/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 132/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 180/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 229/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 260/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 295/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 336/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 370/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 410/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 453/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 490/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 525/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 574/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 604/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 639/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 675/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 712/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 750/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 787/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 824/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 855/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 895/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 921/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 953/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 980/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 105.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 39/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 77/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 127/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 165/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 203/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 237/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 280/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 323/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 364/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 399/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 438/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 472/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 504/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 531/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 570/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 604/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 637/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 671/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 704/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 746/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 781/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 819/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 859/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 896/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 927/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 959/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 987/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 100.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 26/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 56/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 92/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 123/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 164/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 189/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 220/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 246/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 269/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 303/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 337/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 364/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 398/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 426/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 460/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 489/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 522/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 555/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 583/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 606/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 629/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 661/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 698/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 729/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 758/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 785/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 812/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 842/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 868/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 899/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 922/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 957/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 985/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238

# %%
pars_conc_1 = [median(sim_abcsmc_res_conc_1.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#  4.7468031851049535
#  0.3904065026622498
#  1.4561872017235857
#  0.3173701408063346

# %%
true_par
# Out:
# 4-element Array{Float64,1}:
#  5.0
#  1.0e-6
#  1.0
#  1.0

# %% [markdown]
# Print the differences.

# %%
diff = (pars_conc_1 - true_par)
# Out:
# 4-element Array{Float64,1}:
#  -0.25319681489504653
#   0.3904055026622498
#   0.45618720172358573
#  -0.6826298591936655

# %% [markdown]
# Plot an SSA trajectory using the inferred parameters and compare against the experimental SSA.

# %%
single = @time Single_lin(num_sep_all_lins[1], pars_conc_1, v0_n0_th[1]); # do for first gen.
concs_ssa_1 = vcat(single[1:length(single)]...)[:]; expt_c = vcat(expt_ssa_conc...)[:];

fig, axs = PyPlot.subplots(2, 1, sharex = true, tight_layout = true);
axs[2].set_xlabel(L"t"); axs[1].set_ylabel(L"c_{exp}(t)"); axs[2].set_ylabel(L"c_{SSA}(t)"); 
axs[1].plot(range(1,length(expt_c),step=1),expt_c); axs[2].plot(range(1,length(concs_ssa_1),step=1),concs_ssa_1);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
#   0.005560 seconds (16.42 k allocations: 1.570 MiB)

# %% [markdown]
# The inability to infer parameters here seems to arise from the indistinguishability of parameter sets with respect to this objective function of the HD. This is also shown above by the similarity of the behaviour in the concentration trajectories.

# %%
fig, ax = PyPlot.subplots(1, 2, sharey = true);
true_bin_vals_inf, other_stuff = ax[1].hist(concs_ssa_1[:], bins = mod_bins, density = true);
ax[1].set_title("inferred params"); 
true_bin_vals, other_stuff = ax[2].hist(expt_c[:], bins = mod_bins, density = true);
ax[2].set_title("real params");
print("Hellinger distance between these is: ", hellinger(true_bin_vals_inf[:],true_bin_vals[:])) # print the bin values.
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# Hellinger distance between these is: 0.12959175046977392

# %% [markdown]
# ## Run them again!

# %%
n_particles = 1000;
threshold_schedule = [500.0, 250.0, 150.0, 120.0, 110.0, 105.0, 100.0];

priors = [Uniform(0, 10.0), Uniform(0.0, 1.8), Uniform(0, 10.0),
          Uniform(0.0, 1.8)];

sim_abcsmc_res_conc_2 = SimulatedABCSMC(filter_expt_form,
    simulator_function_conc,
    priors,
    threshold_schedule,
    n_particles;
    write_progress=true,
    distance_function = new_distance,
    max_iter = convert(Int,5E4))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053","#E75935","#E84D26","#E84117","#CF3008","#AB2402","#351D17"]
plot(sim_abcsmc_res_conc_2, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 500.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC rejection simulation. Accepted 57/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 103/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 153/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 204/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 265/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 325/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 384/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 438/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 493/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 549/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 592/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 637/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 669/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 704/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 740/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 790/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 852/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 899/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 946/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC SMC simulation ϵ = 250.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 44/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 85/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 132/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 172/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 220/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 257/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 293/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 333/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 375/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 424/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 471/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 514/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 555/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 594/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 633/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 680/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 731/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 773/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 818/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 870/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 917/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 951/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 992/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 150.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 13/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 32/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 44/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 54/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 63/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 72/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 86/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 97/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 111/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 125/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 134/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 145/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 154/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 167/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 183/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 203/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 209/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 222/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 225/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 240/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 248/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 256/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 268/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 276/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 290/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 300/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 316/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 325/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 344/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 352/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 361/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 379/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 391/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 401/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 413/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 425/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 433/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 445/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 453/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 466/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 476/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 491/42000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 501/43000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 511/44000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 527/45000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 542/46000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 556/47000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 570/48000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 585/49000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 600/50000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Warning: Simulation reached maximum 50000 iterations before finding 1000 particles - will return 600
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:248
# ┌ Info: GpABC SMC simulation ϵ = 120.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 31/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 70/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 99/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 139/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 168/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 193/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 215/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 246/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 279/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 303/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 327/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 360/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 396/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 431/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 461/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 479/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 508/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 547/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 588/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 616/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 649/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 683/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 714/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 739/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 774/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 819/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 854/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 884/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 915/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 942/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 976/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 110.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 37/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 71/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 105/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 146/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 185/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 216/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 246/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 274/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 321/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 348/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 382/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 405/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 440/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 466/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 501/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 525/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 558/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 604/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 626/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 659/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 688/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 723/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 753/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 785/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 814/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 840/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 874/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 909/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 936/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 962/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 992/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 105.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 30/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 51/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 78/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 106/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 128/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 161/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 189/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 211/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 230/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 253/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 276/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 310/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 341/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 364/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 389/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 415/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 433/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 461/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 483/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 516/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 546/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 570/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 599/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 636/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 658/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 690/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 708/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 740/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 767/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 795/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 823/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 851/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 881/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 911/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 940/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 965/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 993/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 100.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 27/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 45/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 69/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 89/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 115/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 140/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 161/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 183/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 207/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 221/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 244/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 259/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 282/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 301/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 335/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 356/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 374/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 395/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 413/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 437/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 455/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 477/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 506/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 527/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 557/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 575/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 598/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 617/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 636/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 655/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 678/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 698/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 716/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 736/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 760/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 788/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 814/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 834/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 844/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 868/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 898/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 921/42000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 946/43000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 969/44000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238

# %%
pars_conc_2 = [median(sim_abcsmc_res_conc_2.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#  5.743015663216445
#  0.24389367661618502
#  0.763080864804633
#  0.888433472975594

# %%
true_par
# Out:
# 4-element Array{Float64,1}:
#  5.0
#  1.0e-6
#  1.0
#  1.0

# %% [markdown]
# Print the differences.

# %%
diff_2 = (pars_conc_2 - true_par)
# Out:
# 4-element Array{Float64,1}:
#   0.7430156632164451
#   0.24389267661618502
#  -0.236919135195367
#  -0.11156652702440595

# %%
n_particles = 1000;
threshold_schedule = [500.0, 250.0, 150.0, 120.0, 110.0, 105.0, 100.0];

priors = [Uniform(0, 10.0), Uniform(0.0, 1.8), Uniform(0, 10.0),
          Uniform(0.0, 1.8)];

sim_abcsmc_res_conc_3 = SimulatedABCSMC(filter_expt_form,
    simulator_function_conc,
    priors,
    threshold_schedule,
    n_particles;
    write_progress=true,
    distance_function = new_distance,
    max_iter = convert(Int,5E4))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053","#E75935","#E84D26","#E84117","#CF3008","#AB2402","#351D17"]
plot(sim_abcsmc_res_conc_3, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 500.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC rejection simulation. Accepted 51/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 104/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 151/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 209/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 264/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 326/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 375/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 430/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 489/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 537/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 595/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 647/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 703/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 744/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 786/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 831/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 889/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 941/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 993/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC SMC simulation ϵ = 250.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 40/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 86/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 141/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 192/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 245/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 278/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 325/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 362/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 401/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 437/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 490/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 544/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 585/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 628/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 670/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 703/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 757/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 798/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 828/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 873/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 921/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 967/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 150.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 12/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 29/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 51/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 65/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 83/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 99/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 117/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 134/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 149/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 165/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 178/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 204/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 219/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 228/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 248/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 259/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 278/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 293/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 321/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 336/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 346/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 362/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 384/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 396/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 416/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 435/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 451/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 470/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 487/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 504/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 524/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 536/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 556/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 573/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 586/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 607/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 627/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 647/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 666/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 677/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 692/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 705/42000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 724/43000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 740/44000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 759/45000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 776/46000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 790/47000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 809/48000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 832/49000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 854/50000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Warning: Simulation reached maximum 50000 iterations before finding 1000 particles - will return 854
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:248
# ┌ Info: GpABC SMC simulation ϵ = 120.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 37/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 71/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 111/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 148/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 180/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 216/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 255/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 279/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 327/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 352/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 378/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 408/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 443/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 474/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 517/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 555/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 595/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 629/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 666/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 712/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 739/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 782/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 813/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 839/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 867/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 893/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 928/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 973/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 110.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 26/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 61/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 79/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 117/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 144/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 177/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 208/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 243/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 267/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 293/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 329/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 356/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 379/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 411/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 434/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 449/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 485/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 518/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 563/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 594/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 628/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 666/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 701/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 732/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 764/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 801/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 828/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 860/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 891/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 922/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 953/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 985/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 105.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 22/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 55/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 87/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 121/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 154/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 184/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 218/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 251/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 291/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 323/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 351/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 380/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 416/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 447/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 483/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 510/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 542/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 568/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 593/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 626/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 659/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 691/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 715/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 749/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 778/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 810/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 846/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 878/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 919/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 961/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 986/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 100.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 40/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 97/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 146/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 202/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 262/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 316/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 371/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 423/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 477/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 539/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 591/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 640/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 686/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 734/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 790/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 852/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 898/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 958/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238

# %%
pars_conc_3 = [median(sim_abcsmc_res_conc_3.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#  7.809230665173215
#  0.7253147464864812
#  0.6388227232718847
#  0.3130583443555286

# %%
true_par
# Out:
# 4-element Array{Float64,1}:
#  5.0
#  1.0e-6
#  1.0
#  1.0

# %% [markdown]
# Print the differences.

# %%
diff_3 = (pars_conc_3 - true_par)
# Out:
# 4-element Array{Float64,1}:
#   2.8092306651732146
#   0.7253137464864812
#  -0.3611772767281153
#  -0.6869416556444714

# %% [markdown]
# ## Summary of results

# %% [markdown]
# The model that we are attempting to infer the parameter for is:
# $$\varnothing \xrightarrow{a_1(t)}m\, P\xrightarrow{d}\varnothing,$$
# where $a_1(t) = \alpha_0 V(t)^{\alpha_1}$ and $m$ is a random number drawn from a geometric distribution with time-dependent mean burst size $b(t) = \beta_0 V(t)^{\beta_1}$ and degradation rate $d = 0$. The volume of the system grows according to exponential growth law: $V(t) = V_0 e^{\theta t}$. Later on in this sheet we also go onto assess the minimum threshold for the SMC-ABC data.

# %% [markdown]
# Let's see the inferred medians of the posterior distributions in some tables.

# %%
using DataFrames;

# %%
par_conc = convert(Array{Float64,2},transpose([true_par pars_conc_1 pars_conc_2 pars_conc_3]));
df_conc = DataFrame(alpha_0 = par_conc[:,1], alpha_1 = par_conc[:,2], beta_0 = par_conc[:,3], beta_1 = par_conc[:,4]);

# %%
df_conc
# Out:
# 4×4 DataFrame
# │ Row │ alpha_0 │ alpha_1  │ beta_0   │ beta_1   │
# │     │ Float64 │ Float64  │ Float64  │ Float64  │
# ├─────┼─────────┼──────────┼──────────┼──────────┤
# │ 1   │ 5.0     │ 1.0e-6   │ 1.0      │ 1.0      │
# │ 2   │ 4.7468  │ 0.390407 │ 1.45619  │ 0.31737  │
# │ 3   │ 5.74302 │ 0.243894 │ 0.763081 │ 0.888433 │
# │ 4   │ 7.80923 │ 0.725315 │ 0.638823 │ 0.313058 │
