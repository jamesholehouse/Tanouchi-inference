# %% [markdown]
# # (11.2B) Application of filter with new distance - burst size volume dependence - greater width

# %% [markdown]
# In this notebook we use the new objective function $D_{new} = D_{HD}\times D_{euc}$ in combination with the averaging filter designed in notebook 10. The filter width will be chosen so that the autocorrelation function of the artificial experimental lineage is $1/e$.
#
# Let's start by importing the SSA and the experimental data (only to be used to given initial volumes, molecule numbers and exponential growth rates) and processing it as was done in notebook 5:

# %%
include("./SSA_file.jl"); using .SSAmod;
include("./extract_gens.jl"); using .extract;
using DelimitedFiles;

# %%
filelist = readdir("Analysis_MC4100_37C/MC4100_37C/"); # take the file names - each file is for a different lineage.
raw_data = []; # define the raw data array.
for (i,file) in enumerate(sort!(filelist))
    push!(raw_data,readdlm(string("Analysis_MC4100_37C/MC4100_37C/", file), ',', Float64, '\n'))
end

# %%
fluor_all_lins = [raw_data[x][:,4] for x in 1:length(raw_data)]; # non-separated fluor data.
vol_all_lins = [raw_data[x][:,3] for x in 1:length(raw_data)]; # non-separated vol data.

fluor_sep_all_lins = extract_gens(raw_data,4); # the fluor. data for each lineage sep into gens.
vol_sep_all_lins = extract_gens(raw_data,3); # the vol. data for each lineage sep into gens.
times_sep_all_lins = extract_gens(raw_data,1); # the time pt data for each lineage sep into gens.

fpm = readdlm("MN_props.csv")[1];
exp_grs = readdlm("exp_grs_all.csv", ',', Float64, '\n');

num_sep_all_lins = []; # sep into gens.
for i in 1:length(fluor_sep_all_lins)
    push!(num_sep_all_lins,fluor_sep_all_lins[i]./fpm)
end

# un-sep molecule number and concs for each lineage (including 70th gen to be removed) later).
num_all_lins = [fluor_all_lins[x]./fpm for x in 1:length(fluor_all_lins)];
conc_all_lins = [num_all_lins[x]./vol_all_lins[x] for x in 1:length(fluor_all_lins)];

v0_n0_th = []; # 2-d array to storing (1) the initial values of vol (2) molecule #  and (3) theta for each gen in each lin
for x in 1:length(fluor_all_lins) # the lin loop
    v0_n0_th_x = [];
    for y in 1:length(fluor_sep_all_lins[x]) # the gen loop 1 --> 69
        num = fluor_sep_all_lins[x][y][1]./fpm;
        push!(v0_n0_th_x, [vol_sep_all_lins[x][y][1], num, exp_grs[x,y]])
    end
    push!(v0_n0_th, v0_n0_th_x)
end

# %% [markdown]
# ## Second attempt at inference from artificial data

# %% [markdown]
# Now let's create the experimental data of which we wish to infer the parameters of. We again introduce the lineage function created in notebook 5. We set $\alpha_0 = 5.0$, $\alpha_1 = 0.0$, $\beta_0 = 1.0$ and $\beta_1 = 1.0$:

# %%
true_par = [0.5,0.000001,0.0,1.0];

# %%
lineage_data = num_sep_all_lins[1]; # take the data for the first lineage, this gives the data form for Single_lin.
lin_ic = v0_n0_th[1]; # pre-set params for lineage 1.

function Single_lin(lin_data::Array{Array{Float64,1},1}, inf_par::Array{Float64,1}, ics::Array{Any,1}) # arguments are wrt each lineage.
    SSA_data_c = [];
    for (i,gen) in enumerate(lin_data)
        ssa = SSA_deg_zero_log(1, inf_par, ics[i], length(gen)); # for each gen run the SSA with correct ics.
        push!(SSA_data_c, ssa[2][:]);
    end
    return convert(Array{Array{Float64,1},1},SSA_data_c) # return 
end
# Out:
# Single_lin (generic function with 1 method)

# %% [markdown]
# We take the initial conditions on molecule numbers and volume from lineage 1 of the Tanouchi data, as well as the fluorescence per molecule and exponenital growth rate in each generation.

# %%
expt_ssa_conc = Single_lin(lineage_data, true_par, v0_n0_th[1]);

# %% [markdown]
# Let's plot this data:

# %%
using GpABC, LambertW, Distances, Plots, Distributions, LaTeXStrings, StatsBase, Statistics, LinearAlgebra; pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
PyPlot.plot(range(1,length(vcat(expt_ssa_conc...)[:]),step=1),vcat(expt_ssa_conc...)[:]);
PyPlot.ylabel(L"c_{true}(t)"); PyPlot.xlabel(L"t"); PyPlot.xlim([1,length(vcat(expt_ssa_conc...)[:])]);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Plot the histogram (appropriately chosen x axis) and store the bin values as from the PDF.

# %%
fig, ax = PyPlot.subplots(1,1);
mod_bins = LinRange(0.0, maximum(vcat(expt_ssa_conc...)[:])*1.5, 100);
true_bin_vals, other_stuff = ax.hist(vcat(expt_ssa_conc...)[:], bins = mod_bins, density = true);
print("\n",sum(true_bin_vals*(maximum(vcat(expt_ssa_conc...)[:])*1.5/100))) # check the sum of bins is 1.

true_bin_vals_form = convert(Array{Float64,2},transpose(true_bin_vals));
# Out:
# 0.9900000000000002
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
n = 4;

lin_expt = vcat(expt_ssa_conc...); filter_expt = filter_lin(expt_ssa_conc, n)[2]
filter_expt_form = hcat(filter_expt);

fig, axs = PyPlot.subplots(2, 1, sharex = true, tight_layout = true);
axs[2].set_xlabel(L"t"); axs[1].set_ylabel(L"c_{exp}(t)"); axs[2].set_ylabel(L"c_{filter}(t)"); 
axs[1].plot(range(1,length(lin_expt),step=1),lin_expt); axs[2].plot(range(1,length(filter_expt),step=1),filter_expt);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
# function that returns the SSA concentration for lineage specified abvove.
function simulator_function_conc(var_params::Array{Float64,1})
    lin_conc = filter_lin(Single_lin(lineage_data, var_params, lin_ic)[:], n)[2] # choose up-sep form [2]
    return hcat(lin_conc)::Array{Float64,2}
end
# Out:
# simulator_function_conc (generic function with 1 method)

# %% [markdown]
# Create the new distance function that takes in the sample trajectory vector and experimental trajectory as inputs and outputs the product of the hellinger distance and the euclidean distance between the two trajectories.

# %%
function new_distance(samp_traj::Array{Float64,1}, exp_traj::Array{Float64,1})
    euc_dist = euclidean(samp_traj[:], exp_traj[:]); # euclidean distance
    samp_bins = normalize(fit(Histogram, samp_traj[:], mod_bins), mode=:probability).weights;
    exp_bins = normalize(fit(Histogram, exp_traj[:], mod_bins), mode=:probability).weights;
    hell_dist = hellinger(samp_bins, exp_bins); # HD
    
    return euc_dist*hell_dist::Float64 # return the product
end
# Out:
# new_distance (generic function with 1 method)

# %%
thres_cutoff = sum(new_distance(simulator_function_conc(true_par)[:], filter_expt_form[:]) for i in 1:1000)/1000
# Out:
# 82.26697324421235

# %%
@time new_distance(simulator_function_conc(true_par)[:], filter_expt_form[:])
# Out:
#   0.003017 seconds (14.61 k allocations: 1.240 MiB)
# 97.77561583778984

# %%
n_particles = 500;
threshold_schedule = [500.0, 300.0, 250.0, 200.0, 150.0, 110.0, 90.0, 85.0];

priors = [Uniform(-1.0,1.0), Uniform(0.0, 1.0), Uniform(-1.0,1.0),
          Uniform(0.0, 1.8)];

sim_abcsmc_res_conc_1 = SimulatedABCSMC(filter_expt_form,
    simulator_function_conc,
    priors,
    threshold_schedule,
    n_particles;
    write_progress=true,
    distance_function = new_distance,
    max_iter = convert(Int,1E5))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053"]#,"#E75935","#E84D26","#E84117","#CF3008","#AB2402","#351D17"]
plot(sim_abcsmc_res_conc_1, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 500.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC rejection simulation. Accepted 160/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 357/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC SMC simulation ϵ = 300.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 115/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 240/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 373/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 497/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 250.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 142/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 273/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 416/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 200.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 131/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 256/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 389/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 150.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 121/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 247/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 384/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 494/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 110.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 78/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 161/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 235/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 304/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 383/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 462/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 90.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 53/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 90/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 134/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 183/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 239/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 274/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 311/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 358/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 414/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 447/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 491/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 85.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 20/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 59/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 93/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 118/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 153/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 176/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 208/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 244/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 276/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 318/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 353/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 400/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 424/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 465/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 498/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238

# %%
pars_conc_1 = [median(sim_abcsmc_res_conc_1.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#   0.7181108919807697
#   0.6269395363231828
#  -0.41571730281748276
#   0.8241374849217069

# %%
true_par
# Out:
# 4-element Array{Float64,1}:
#  0.5
#  1.0e-6
#  0.0
#  1.0

# %% [markdown]
# Print the differences.

# %%
diff = (pars_conc_1 - true_par)
# Out:
# 4-element Array{Float64,1}:
#   0.21811089198076972
#   0.6269385363231827
#  -0.41571730281748276
#  -0.1758625150782931

# %% [markdown]
# Plot an SSA trajectory using the inferred parameters and compare against the experimental SSA.

# %%
single = @time Single_lin(num_sep_all_lins[1], pars_conc_1, v0_n0_th[1]); # do for first gen.
concs_ssa_1 = vcat(single[1:length(single)]...)[:]; expt_c = vcat(expt_ssa_conc...)[:];

fig, axs = PyPlot.subplots(2, 1, sharex = true, tight_layout = true);
axs[2].set_xlabel(L"t"); axs[1].set_ylabel(L"c_{exp}(t)"); axs[2].set_ylabel(L"c_{SSA}(t)"); 
axs[1].plot(range(1,length(expt_c),step=1),expt_c); axs[2].plot(range(1,length(concs_ssa_1),step=1),concs_ssa_1);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
#   0.008878 seconds (23.38 k allocations: 2.207 MiB)

# %% [markdown]
# The inability to infer parameters here seems to arise from the indistinguishability of parameter sets with respect to this objective function of the HD. This is also shown above by the similarity of the behaviour in the concentration trajectories.

# %%
fig, ax = PyPlot.subplots(1, 2, sharey = true);
true_bin_vals_inf, other_stuff = ax[1].hist(concs_ssa_1[:], bins = mod_bins, density = true);
ax[1].set_title("inferred params"); 
true_bin_vals, other_stuff = ax[2].hist(expt_c[:], bins = mod_bins, density = true);
ax[2].set_title("real params");
print("Hellinger distance between these is: ", hellinger(true_bin_vals_inf[:],true_bin_vals[:])) # print the bin values.
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# Hellinger distance between these is: 0.11486877652782812

# %% [markdown]
# ## Run them again!

# %%
n_particles = 500;
threshold_schedule = [500.0, 300.0, 250.0, 200.0, 150.0, 110.0, 90.0, 85.0];

priors = [Uniform(-1.0,1.0), Uniform(0.0, 1.0), Uniform(-1.0,1.0),
          Uniform(0.0, 1.8)];

sim_abcsmc_res_conc_2 = SimulatedABCSMC(filter_expt_form,
    simulator_function_conc,
    priors,
    threshold_schedule,
    n_particles;
    write_progress=true,
    distance_function = new_distance,
    max_iter = convert(Int,1E5))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053","#E75935","#E84D26","#E84117","#CF3008","#AB2402","#351D17"]
plot(sim_abcsmc_res_conc_2, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 500.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC rejection simulation. Accepted 172/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 334/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC SMC simulation ϵ = 300.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 142/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 294/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 436/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 250.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 123/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 250/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 356/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 473/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 200.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 94/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 189/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 300/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 396/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 150.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 111/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 216/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 307/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 419/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 110.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 64/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 126/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 203/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 268/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 351/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 421/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 90.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 43/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 78/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 106/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 135/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 166/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 197/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 224/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 255/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 297/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 328/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 356/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 391/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 416/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 458/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 493/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 85.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 26/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 47/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 72/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 97/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 120/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 145/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 170/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 199/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 224/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 254/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 282/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 308/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 331/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 353/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 376/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 397/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 425/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 448/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 469/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 495/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238

# %%
pars_conc_2 = [median(sim_abcsmc_res_conc_2.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#  0.3982080195396238
#  0.4176950458472916
#  0.05489262935990205
#  0.6737041127443916

# %%
true_par
# Out:
# 4-element Array{Float64,1}:
#  0.5
#  1.0e-6
#  0.0
#  1.0

# %% [markdown]
# Print the differences.

# %%
diff_2 = (pars_conc_2 - true_par)
# Out:
# 4-element Array{Float64,1}:
#  -0.10179198046037619
#   0.41769404584729164
#   0.05489262935990205
#  -0.32629588725560843

# %%
n_particles = 500;
threshold_schedule = [500.0, 300.0, 250.0, 200.0, 150.0, 110.0, 90.0, 85.0];

priors = [Uniform(-1.0,1.0), Uniform(0.0, 1.0), Uniform(-1.0,1.0),
          Uniform(0.0, 1.8)];

sim_abcsmc_res_conc_3 = SimulatedABCSMC(filter_expt_form,
    simulator_function_conc,
    priors,
    threshold_schedule,
    n_particles;
    write_progress=true,
    distance_function = new_distance,
    max_iter = convert(Int,1E5))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053","#E75935","#E84D26","#E84117","#CF3008","#AB2402","#351D17"]
plot(sim_abcsmc_res_conc_3, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 500.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC rejection simulation. Accepted 171/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC rejection simulation. Accepted 354/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC SMC simulation ϵ = 300.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 139/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 291/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 421/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 250.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 148/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 308/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 471/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 200.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 188/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 377/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 150.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 137/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 295/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 449/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 110.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 92/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 169/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 243/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 330/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 403/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 477/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 90.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 48/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 101/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 137/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 179/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 230/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 271/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 316/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 361/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 408/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 456/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 85.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 28/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 59/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 86/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 108/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 134/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 167/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 201/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 239/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 266/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 286/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 322/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 360/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 394/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 418/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 450/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 486/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238

# %%
pars_conc_3 = [median(sim_abcsmc_res_conc_3.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#   0.6977521270862986
#   0.3614339007281495
#  -0.38820771850072844
#   1.055675356645535

# %%
true_par
# Out:
# 4-element Array{Float64,1}:
#  0.5
#  1.0e-6
#  0.0
#  1.0

# %% [markdown]
# Print the differences.

# %%
diff_3 = (pars_conc_3 - true_par)
# Out:
# 4-element Array{Float64,1}:
#   0.19775212708629863
#   0.36143290072814954
#  -0.38820771850072844
#   0.055675356645535024

# %% [markdown]
# ## Summary of results

# %% [markdown]
# The model that we are attempting to infer the parameter for is:
# $$\varnothing \xrightarrow{a_1(t)}m\, P\xrightarrow{d}\varnothing,$$
# where $a_1(t) = \alpha_0 V(t)^{\alpha_1}$ and $m$ is a random number drawn from a geometric distribution with time-dependent mean burst size $b(t) = \beta_0 V(t)^{\beta_1}$ and degradation rate $d = 0$. The volume of the system grows according to exponential growth law: $V(t) = V_0 e^{\theta t}$. Later on in this sheet we also go onto assess the minimum threshold for the SMC-ABC data.

# %% [markdown]
# Let's see the inferred medians of the posterior distributions in some tables.

# %%
using DataFrames;

# %%
par_conc = convert(Array{Float64,2},transpose([true_par pars_conc_1 pars_conc_2 pars_conc_3]));
df_conc = DataFrame(alpha_0 = 10 .^par_conc[:,1], alpha_1 = par_conc[:,2], beta_0 = 10 .^par_conc[:,3], beta_1 = par_conc[:,4]);

# %%
df_conc
# Out:
# 4×4 DataFrame
# │ Row │ alpha_0 │ alpha_1  │ beta_0   │ beta_1   │
# │     │ Float64 │ Float64  │ Float64  │ Float64  │
# ├─────┼─────────┼──────────┼──────────┼──────────┤
# │ 1   │ 3.16228 │ 1.0e-6   │ 1.0      │ 1.0      │
# │ 2   │ 5.2253  │ 0.62694  │ 0.383957 │ 0.824137 │
# │ 3   │ 2.50154 │ 0.417695 │ 1.13473  │ 0.673704 │
# │ 4   │ 4.986   │ 0.361434 │ 0.409065 │ 1.05568  │
