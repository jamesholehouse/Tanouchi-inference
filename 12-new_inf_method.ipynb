# %% [markdown]
# # (12)

# %% [markdown]
# ...

# %%
include("./SSA_file.jl"); using .SSAmod;
include("./extract_gens.jl"); using .extract;
using DelimitedFiles;

# %%
filelist = readdir("Analysis_MC4100_37C/MC4100_37C/"); # take the file names - each file is for a different lineage.
raw_data = []; # define the raw data array.
for (i,file) in enumerate(sort!(filelist))
    push!(raw_data,readdlm(string("Analysis_MC4100_37C/MC4100_37C/", file), ',', Float64, '\n'))
end

# %%
fluor_all_lins = [raw_data[x][:,4] for x in 1:length(raw_data)]; # non-separated fluor data.
vol_all_lins = [raw_data[x][:,3] for x in 1:length(raw_data)]; # non-separated vol data.

fluor_sep_all_lins = extract_gens(raw_data,4); # the fluor. data for each lineage sep into gens.
vol_sep_all_lins = extract_gens(raw_data,3); # the vol. data for each lineage sep into gens.
times_sep_all_lins = extract_gens(raw_data,1); # the time pt data for each lineage sep into gens.

fpm = readdlm("MN_props.csv")[1];
exp_grs = readdlm("exp_grs_all.csv", ',', Float64, '\n');

num_sep_all_lins = []; # sep into gens.
conc_sep_all_lins = [];
for i in 1:length(fluor_sep_all_lins)
    num_i = fluor_sep_all_lins[i]./fpm;
    conc_i = [num_i[y] ./ vol_sep_all_lins[i][y] for y in 1:length(vol_sep_all_lins[i])];
    push!(num_sep_all_lins,num_i);
    push!(conc_sep_all_lins,conc_i);
end

# un-sep molecule number and concs for each lineage (including 70th gen to be removed) later).
num_all_lins = [fluor_all_lins[x]./fpm for x in 1:length(fluor_all_lins)];
conc_all_lins = [num_all_lins[x]./vol_all_lins[x] for x in 1:length(fluor_all_lins)];

v0_n0_th = []; # 2-d array to storing (1) the initial values of vol (2) molecule #  and (3) theta for each gen in each lin
for x in 1:length(fluor_all_lins) # the lin loop
    v0_n0_th_x = [];
    for y in 1:length(fluor_sep_all_lins[x]) # the gen loop 1 --> 69
        num = fluor_sep_all_lins[x][y][1]./fpm;
        push!(v0_n0_th_x, [vol_sep_all_lins[x][y][1], num, exp_grs[x,y]])
    end
    push!(v0_n0_th, v0_n0_th_x)
end

# %% [markdown]
# Now, let's plot all the generation concentration trajectories for the first lineage.

# %%
using Plots, Statistics, StatsBase, Distances, Distributions, GpABC, LaTeXStrings, LinearAlgebra; pyplot();

# %%
conc_gens = conc_sep_all_lins[1];
fig, ax = PyPlot.subplots(1,1);
for i in 1:length(conc_gens)
    ax.plot(conc_gens[i])
end
PyPlot.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Need to make all generation arrays the same length if I am to convert the `conc_gens` `Array{Array{Float64,1}}` to a `Array{Float64,2}` array.

# %%
# find the longest generation
max_len = maximum([length(gen) for gen in conc_gens]);
[length(gen) for gen in conc_gens]
# Out:
# 69-element Array{Int64,1}:
#  33
#  26
#  26
#  36
#  23
#  22
#  41
#  36
#  40
#  32
#  41
#  27
#  32
#   ⋮
#  37
#  26
#  37
#  31
#  26
#  34
#  29
#  33
#  32
#  31
#  37
#  28

# %%
norm_gens_temp = []; # new conc gens array with added NaNs to make all the same length.
for gen in conc_gens
    gen_len = length(gen)
    new_gen = copy(gen)
    add_nans = [NaN for i in 1:(max_len-gen_len)]
    append!(new_gen, add_nans)
    push!(norm_gens_temp, new_gen)
end

# %%
norm_gens = convert(Array{Float64,2},transpose(hcat(norm_gens_temp...)))
# Out:
# 69×55 Array{Float64,2}:
#  145.52   147.189   145.765   147.438   …  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  165.588  156.213   163.433   162.739      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  149.631  136.042   145.111   147.277      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  126.334  136.926   136.771   129.459      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  126.443  115.388   121.813   121.676      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  112.391  107.843   114.501   115.2     …  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#   98.545  100.887    91.5151   97.0485     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  101.66   101.88    101.007   106.03       NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  122.685  123.377   122.69    130.835      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  124.114  124.248   122.522   109.474      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  101.664  107.956   115.152   113.36    …  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  113.286  121.836   111.112   105.531      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  116.48   121.648   118.522   120.807      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#    ⋮                                    ⋱              ⋮
#  120.599  115.79    123.24    119.82       NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  114.366  118.578   117.992   122.794      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  112.166   99.1049  114.183   119.179      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  117.822  119.68    115.048   119.81    …  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  122.193  119.837   118.532   118.56       NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  116.585  116.5     109.927   116.66       NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  116.445  115.51    120.805   112.954      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  124.738  117.119   116.234   119.878      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  110.617  108.125   121.474   114.561   …  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  105.744  109.14    112.249   111.311      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  112.163  115.87    118.24    125.836      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  123.704  120.777   130.037   119.195      NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
norm_gens[1,:]; # gives the first lineage.
norm_gens[:,1]; # gives first timepts.
print(mean(filter(!isnan, norm_gens[1,:])),"\n") # removes the NaNs
print(mean(norm_gens[1,:])) # does not remove NaNs
# Out:
# 152.60454608379806
# NaN

# %% [markdown]
# Let's produce some histograms over the data.

# %%
fig, ax = PyPlot.subplots(1,1);
time_bins = LinRange(0.0, 180.0, 35);
hist1, os = ax.hist(norm_gens[:,10], bins = time_bins, density = true, alpha = 0.5, label = "10 min"); 
hist2, os = ax.hist(norm_gens[:,20], color = "r", bins = time_bins, density = true, alpha = 0.5, label = "20 min"); 
hist3, os = ax.hist(norm_gens[:,30], color = "g", bins = time_bins, density = true, alpha = 0.5, label = "30 min"); 
ax.grid(true); ax.set_xlabel(L"Concentration (C)$.$"); ax.set_ylabel(L"$P(C)$"); ax.legend()
PyPlot.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
@time hellinger(hist1, hist2)
# Out:
#   0.019938 seconds (55.07 k allocations: 3.014 MiB)
# 0.19249873296605996

# %% [markdown]
# # Artificial data: burst size dependence on volume.

# %% [markdown]
# Now let's do the same for some artificial data.

# %%
#true_par = [0.025,1.0,0.5,0.000001]; # one can see below that switching the volume dependency leads to much worse concentration histograms.
true_par = [0.3,0.000001,0.25,1.0];

# %%
lineage_data = conc_sep_all_lins[1]; # take the data for the first lineage, this gives the data form for Single_lin.
lin_ic = v0_n0_th[1]; # pre-set params for lineage 1.

function Single_lin(lin_data::Array{Array{Float64,1},1}, inf_par::Array{Float64,1}, ics::Array{Any,1}) # arguments are wrt each lineage.
    SSA_data_c = [];
    for (i,gen) in enumerate(lin_data)
        ssa = SSA_deg_zero_log(1, inf_par, ics[i], length(gen)); # for each gen run the SSA with correct ics.
        push!(SSA_data_c, ssa[2][:]);
    end
    return vcat(SSA_data_c)# return in the same order as the SSA.
end
# Out:
# Single_lin (generic function with 1 method)

# %% [markdown]
# We take the initial conditions on molecule numbers and volume from lineage 1 of the Tanouchi data, as well as the fluorescence per molecule and exponenital growth rate in each generation.

# %%
expt_ssa_conc = Single_lin(conc_gens, true_par, v0_n0_th[1]);

# %%
lineage_data;

# %%
conc_gens_art = expt_ssa_conc;
fig, ax = PyPlot.subplots(1,1);
for i in 1:length(conc_gens)
    ax.plot(conc_gens_art[i])
end
PyPlot.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Need to make all generation arrays the same length if I am to convert the `conc_gens` `Array{Array{Float64,1}}` to a `Array{Float64,2}` array.

# %%
# find the longest generation
max_len_art = maximum([length(gen) for gen in conc_gens_art])
# Out:
# 55

# %%
norm_gens_temp_art = []; # new conc gens array with added NaNs to make all the same length.
for gen in conc_gens_art
    gen_len = length(gen)
    new_gen_art = gen
    add_nans = [NaN for i in 1:(max_len_art-gen_len)]
    append!(new_gen_art, add_nans)
    push!(norm_gens_temp_art, new_gen_art)
end

# %%
norm_gens_art = convert(Array{Float64,2},transpose(hcat(norm_gens_temp_art...)));

# %%
norm_gens_art[1,:]; # gives the first lineage.
norm_gens_art[:,1]; # gives first timepts.
print(mean(filter(!isnan, norm_gens_art[1,:])),"\n") # removes the NaNs
print(mean(norm_gens_art[1,:])) # does not remove NaNs
# Out:
# 135.649638460613
# NaN

# %% [markdown]
# Let's produce some histograms over the data.

# %%
fig, ax = PyPlot.subplots(1,1);
time_bins = LinRange(0.0, 180.0, 35);
hist1_art, os = ax.hist(norm_gens_art[:,10], bins = time_bins, density = true, alpha = 0.5, label = "10 min"); 
hist2_art, os = ax.hist(norm_gens_art[:,20], color = "r", bins = time_bins, density = true, alpha = 0.5, label = "20 min"); 
hist3_art, os = ax.hist(norm_gens_art[:,30], color = "g", bins = time_bins, density = true, alpha = 0.5, label = "30 min"); 
ax.grid(true); ax.set_xlabel(L"Concentration (C)$.$"); ax.set_ylabel(L"$P(C)$"); ax.legend()
PyPlot.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
@time print(hellinger(hist1, hist1_art), "\n", hellinger(hist2, hist2_art), "\n", hellinger(hist3, hist3_art), "\n")
# Out:
# 0.2864545774820246
# 0.27342585595524155
# 0.37588303574492543
#   0.016376 seconds (20.90 k allocations: 1.107 MiB)

# %% [markdown]
# Plot the histogram (appropriately chosen x axis) and store the bin values as from the PDF.

# %%
all_pts = vcat(filter(!isnan,vcat(conc_gens...)));
all_pts_SSA = vcat(filter(!isnan,vcat(expt_ssa_conc...)));

# %%
fig, ax = PyPlot.subplots(1,1);
mod_bins = LinRange(0.0, maximum(all_pts)*1.5, 100);
true_bin_vals, other_stuff = ax.hist(all_pts, bins = mod_bins, density = true, alpha = 0.5);
SSA_bin_vals, other_stuff = ax.hist(all_pts_SSA, bins = mod_bins, density = true, alpha = 0.5, color = "r");


print("The HD between these two distributions is: ",hellinger(true_bin_vals, SSA_bin_vals)) # check the sum of bins is 1.

true_bin_vals_form = convert(Array{Float64,2},transpose(true_bin_vals));
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# The HD between these two distributions is: 0.17273533513370218

# %% [markdown]
# Now let's set up the tools needed to perform the inference of the parameters as we did in notebook 5. In this case the output will be the bin values for the histogram of the trajectory. Later we will specify the Hellinger distance measure in the SMC-ABC options.

# %%
# function that returns the SSA concentration for lineage specified abvove.
function simulator_function_conc(var_params::Array{Float64,1})
    lin_conc = Single_lin(lineage_data, var_params, lin_ic)
    return lin_conc::Array{Float64,2}
end
# Out:
# simulator_function_conc (generic function with 1 method)

# %% [markdown]
# # Artificial data: transcription rate dependence on volume.

# %% [markdown]
# Now let's do the same for some artificial data.

# %%
true_par = [0.025,1.0,0.5,0.000001]; # one can see below that switching the volume dependency leads to much worse concentration histograms.

# %%
lineage_data = conc_sep_all_lins[1]; # take the data for the first lineage, this gives the data form for Single_lin.
lin_ic = v0_n0_th[1]; # pre-set params for lineage 1.

function Single_lin(lin_data::Array{Array{Float64,1},1}, inf_par::Array{Float64,1}, ics::Array{Any,1}) # arguments are wrt each lineage.
    SSA_data_c = [];
    for (i,gen) in enumerate(lin_data)
        ssa = SSA_deg_zero_log(1, inf_par, ics[i], length(gen)); # for each gen run the SSA with correct ics.
        push!(SSA_data_c, ssa[2][:]);
    end
    return vcat(SSA_data_c)# return in the same order as the SSA.
end
# Out:
# Single_lin (generic function with 1 method)

# %% [markdown]
# We take the initial conditions on molecule numbers and volume from lineage 1 of the Tanouchi data, as well as the fluorescence per molecule and exponenital growth rate in each generation.

# %%
expt_ssa_conc = Single_lin(conc_gens, true_par, v0_n0_th[1]);

# %%
lineage_data;

# %%
conc_gens_art = expt_ssa_conc;
fig, ax = PyPlot.subplots(1,1);
for i in 1:length(conc_gens)
    ax.plot(conc_gens_art[i])
end
PyPlot.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Need to make all generation arrays the same length if I am to convert the `conc_gens` `Array{Array{Float64,1}}` to a `Array{Float64,2}` array.

# %%
# find the longest generation
max_len_art = maximum([length(gen) for gen in conc_gens_art])
# Out:
# 55

# %%
norm_gens_temp_art = []; # new conc gens array with added NaNs to make all the same length.
for gen in conc_gens_art
    gen_len = length(gen)
    new_gen_art = gen
    add_nans = [NaN for i in 1:(max_len_art-gen_len)]
    append!(new_gen_art, add_nans)
    push!(norm_gens_temp_art, new_gen_art)
end

# %%
norm_gens_art = convert(Array{Float64,2},transpose(hcat(norm_gens_temp_art...)))
# Out:
# 69×55 Array{Float64,2}:
#  145.52   149.777   180.925  178.159  …  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  165.588  161.463   161.193  168.524     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  149.631  147.66    145.228  143.252     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  126.334  127.104   125.344  125.429     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  126.443  122.635   125.262  121.49      NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  112.391  110.479   113.712  114.221  …  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#   98.545   96.2214  102.766  102.802     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  101.66   104.816   106.701  104.253     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  122.685  125.194   122.122  121.459     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  124.114  129.139   129.983  128.035     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  101.664  110.785   110.924  111.467  …  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  113.286  110.334   111.282  109.623     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  116.48   122.098   120.074  118.497     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#    ⋮                                  ⋱              ⋮
#  120.599  118.545   115.496  114.516     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  114.366  118.075   114.966  119.585     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  112.166  112.286   109.49   107.318     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  117.822  114.547   114.095  113.581  …  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  122.193  128.657   129.549  126.319     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  116.585  119.93    120.242  117.746     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  116.445  113.26    112.565  109.954     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  124.738  121.52    124.12   122.442     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  110.617  112.764   125.584  126.448  …  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  105.744  104.279   101.838  101.381     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  112.163  109.198   108.75   105.876     NaN  NaN  NaN  NaN  NaN  NaN  NaN
#  123.704  120.393   119.877  117.546     NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
norm_gens_art[1,:]; # gives the first lineage.
norm_gens_art[:,1]; # gives first timepts.
print(mean(filter(!isnan, norm_gens_art[1,:])),"\n") # removes the NaNs
print(mean(norm_gens_art[1,:])) # does not remove NaNs
# Out:
# 166.71566731190055
# NaN

# %% [markdown]
# Let's produce some histograms over the data.

# %%
fig, ax = PyPlot.subplots(1,1);
time_bins = LinRange(0.0, 180.0, 35);
hist1_art, os = ax.hist(norm_gens_art[:,10], bins = time_bins, density = true, alpha = 0.5, label = "10 min"); 
hist2_art, os = ax.hist(norm_gens_art[:,20], color = "r", bins = time_bins, density = true, alpha = 0.5, label = "20 min"); 
hist3_art, os = ax.hist(norm_gens_art[:,30], color = "g", bins = time_bins, density = true, alpha = 0.5, label = "30 min"); 
ax.grid(true); ax.set_xlabel(L"Concentration (C)$.$"); ax.set_ylabel(L"$P(C)$"); ax.legend()
PyPlot.show()
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
@time print(hellinger(hist1, hist1_art), "\n", hellinger(hist2, hist2_art), "\n", hellinger(hist3, hist3_art), "\n")
# Out:
# 0.2622585901095119
# 0.3224275903884203
# 0.37530444461729234
#   0.000083 seconds (106 allocations: 3.797 KiB)

# %% [markdown]
# Plot the histogram (appropriately chosen x axis) and store the bin values as from the PDF.

# %%
all_pts = vcat(filter(!isnan,vcat(conc_gens...)));
all_pts_SSA = vcat(filter(!isnan,vcat(expt_ssa_conc...)));

# %%
fig, ax = PyPlot.subplots(1,1);
mod_bins = LinRange(0.0, maximum(all_pts)*1.5, 100);
true_bin_vals, other_stuff = ax.hist(all_pts, bins = mod_bins, density = true, alpha = 0.5);
SSA_bin_vals, other_stuff = ax.hist(all_pts_SSA, bins = mod_bins, density = true, alpha = 0.5, color = "r");


print("The HD between these two distributions is: ",hellinger(true_bin_vals, SSA_bin_vals)) # check the sum of bins is 1.

true_bin_vals_form = convert(Array{Float64,2},transpose(true_bin_vals));
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)
# The HD between these two distributions is: 0.16141412247767034

# %% [markdown]
# # Inference set-up

# %% [markdown]
# ## Transcription rate volume dependence

# %% [markdown]
# Now let's set up the tools needed to perform the inference of the parameters as we did in notebook 5. In this case the output will be the bin values for the histogram of the trajectory. Later we will specify the Hellinger distance measure in the SMC-ABC options.

# %%
# function that returns the SSA concentration for lineage specified abvove.
function simulator_function_conc(var_params::Array{Float64,1})
    lin_conc = Single_lin(lineage_data, var_params, lin_ic)
    return hcat(vcat(lin_conc...))
end
# Out:
# simulator_function_conc (generic function with 1 method)

# %% [markdown]
# Define function that takes in the 1-D array of un-separated generations and returns the separated 2-D array in terms of generations.

# %%
conc_gens = conc_sep_all_lins[1]; # take this for the data structure.
function make_2d(flat_arr::Array{Float64,1})
    # take lengths of each gen
    dims = [length(conc_gens[x]) for x in 1:length(conc_gens)];
    cum_dims = prepend!([sum(dims[1:y]) for y in 1:length(dims)],1);
    new_arr = [flat_arr[cum_dims[i]:cum_dims[i+1]] for i in 1:length(dims)];
    return new_arr
end
# Out:
# make_2d (generic function with 1 method)

# %% [markdown]
# Set-up the artificial SSA trajectory.

# %%
true_par
# Out:
# 4-element Array{Float64,1}:
#  0.025
#  1.0
#  0.5
#  1.0e-6

# %%
art_data = simulator_function_conc(true_par);

# %%
function new_distance(flat_lin_1::Array{Float64,1}, flat_lin_2::Array{Float64,1})
    lin_1 = make_2d(flat_lin_1[:]); lin_2 = make_2d(flat_lin_2[:]);
    max_len = maximum([length(gen) for gen in lin_1]);
    lin_1_new = []; lin_2_new = []; # NaN padded lin arrays.
    
    for i in 1:length(lin_1) # add NaNs to lins
        gen_len = length(lin_1[i]); new_gen_1 = copy(lin_1[i]); new_gen_2 = copy(lin_2[i]);
        add_nans = [NaN for i in 1:(max_len - gen_len)]
        append!(new_gen_1, add_nans); append!(new_gen_2, add_nans); 
        push!(lin_1_new, new_gen_1); push!(lin_2_new, new_gen_2);
    end
    
    sq_lin_1 = convert(Array{Float64,2},transpose(hcat(lin_1_new...)));
    sq_lin_2 = convert(Array{Float64,2},transpose(hcat(lin_2_new...)));

    num_slices = 10;
    max_HD_time = round(Int64, 0.75*max_len);
    HD_times = [j*max_HD_time ÷ num_slices for j in 1:num_slices];
    
    all_pts_1 = vcat(lin_1...); 
    all_pts_2 = vcat(lin_2...);
    traj_bins = LinRange(0.0, maximum(all_pts_2)*1.5, 100);
    tdist_1 = normalize(fit(Histogram, all_pts_1, traj_bins), mode=:probability).weights;
    tdist_2 = normalize(fit(Histogram, all_pts_2, traj_bins), mode=:probability).weights;
    traj_HD = hellinger(tdist_1, tdist_2);
    
    time_bins = LinRange(0.0, maximum(all_pts_2)*1.5, 35);
    lin_1_dists = [normalize(fit(Histogram, filter(!isnan,sq_lin_1[:,HD_times[x]]), time_bins), mode=:probability).weights for x in 1:num_slices];
    lin_2_dists = [normalize(fit(Histogram, filter(!isnan,sq_lin_2[:,HD_times[x]]), time_bins), mode=:probability).weights for x in 1:num_slices];
    HD_slices = sum([hellinger(lin_1_dists[y], lin_2_dists[y]) for y in 1:num_slices]); # could do product??

    #return traj_HD*HD_slices
    return HD_slices
end
# Out:
# new_distance (generic function with 1 method)

# %%
sum([new_distance(vcat(simulator_function_conc(true_par)...),vcat(simulator_function_conc(true_par)...)) for i in 1:1000])/1000
# Out:
# 2.825178284259246

# %%
n_particles = 1000;
#threshold_schedule = [2.5, 1.25, 0.75, 0.5, 0.4, 0.3, 0.25, 0.2, 0.15, 0.12];
threshold_schedule = [8.0, 6.0, 5.0, 4.0, 3.5, 3.0, 2.8];

priors = [Uniform(-0.5, 0.5), Uniform(0.0, 1.3), Uniform(0.0, 1.0),
          Uniform(0.0, 1.3)];

sim_abcsmc_res_conc_1 = SimulatedABCSMC(art_data,
    simulator_function_conc,
    priors,
    threshold_schedule,
    n_particles;
    write_progress=true,
    distance_function = new_distance,
    max_iter = convert(Int,1E5))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053","#E75935","#E84D26","#E84117","#CF3008","#AB2402","#351D17"]
plot(sim_abcsmc_res_conc_1, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 8.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC rejection simulation. Accepted 617/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC SMC simulation ϵ = 6.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 370/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 741/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 5.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 253/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 517/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 796/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 4.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 110/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 238/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 356/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 473/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 593/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 702/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 809/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 934/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 3.5
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 53/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 112/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 174/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 235/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 304/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 355/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 418/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 479/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 536/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 595/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 651/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 721/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 768/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 824/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 877/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 934/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 996/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 3.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 10/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 13/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 19/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 22/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 29/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 34/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 40/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 44/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 49/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 56/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 61/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 65/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 67/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 74/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 77/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 83/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 86/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 90/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 93/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 96/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 100/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 103/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 110/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 114/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 119/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 129/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 133/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 143/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 149/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 157/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 162/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 165/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 171/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 176/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 180/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 186/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 187/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 196/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 200/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 210/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 212/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 219/42000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 229/43000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 239/44000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 244/45000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 247/46000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 255/47000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 257/48000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 267/49000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 274/50000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 278/51000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 287/52000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 290/53000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 297/54000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 304/55000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 307/56000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 311/57000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 318/58000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 320/59000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 333/60000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 340/61000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 349/62000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 350/63000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 352/64000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 358/65000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 360/66000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 366/67000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 371/68000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 375/69000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 382/70000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 386/71000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 396/72000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 401/73000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 404/74000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 409/75000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 416/76000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 425/77000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 436/78000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 440/79000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 444/80000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 451/81000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 459/82000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 464/83000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 472/84000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 480/85000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 486/86000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 494/87000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 499/88000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 503/89000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 508/90000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 515/91000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 522/92000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 530/93000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 537/94000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 543/95000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 552/96000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 555/97000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 561/98000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 567/99000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 577/100000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Warning: Simulation reached maximum 100000 iterations before finding 1000 particles - will return 577
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:248
# ┌ Info: GpABC SMC simulation ϵ = 2.8
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 8/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 10/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 16/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 19/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 24/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 32/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 37/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 44/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 54/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 58/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 64/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 67/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 69/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 73/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 74/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 83/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 88/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 93/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 96/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 103/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 108/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 111/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 115/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 121/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 129/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 134/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 137/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 142/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 143/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 149/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 150/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 157/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 161/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 164/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 174/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 179/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 182/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 186/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 190/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 193/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 199/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 202/42000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 206/43000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 210/44000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 216/45000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 224/46000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 227/47000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 230/48000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 238/49000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 246/50000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 249/51000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 255/52000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 261/53000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 265/54000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 273/55000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 279/56000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 283/57000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 285/58000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 287/59000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 292/60000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 298/61000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 302/62000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 312/63000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 315/64000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 318/65000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 323/66000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 327/67000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 331/68000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 333/69000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 339/70000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 342/71000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 347/72000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 351/73000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 355/74000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 366/75000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 370/76000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 378/77000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 382/78000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 385/79000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 387/80000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 394/81000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 398/82000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 401/83000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 406/84000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 409/85000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 418/86000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 424/87000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 428/88000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 430/89000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 433/90000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 438/91000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 444/92000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 448/93000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 450/94000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 453/95000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 458/96000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 461/97000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 465/98000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 475/99000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 484/100000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Warning: Simulation reached maximum 100000 iterations before finding 1000 particles - will return 484
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:248

# %%
pars_conc_1 = [median(sim_abcsmc_res_conc_1.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#  0.08381986243355494
#  0.7113090412085858
#  0.41500935300174635
#  0.28857862058932127

# %%
true_par
# Out:
# 4-element Array{Float64,1}:
#  0.025
#  1.0
#  0.5
#  1.0e-6

# %%
single = @time Single_lin(num_sep_all_lins[1], pars_conc_1, v0_n0_th[1]); # do for first gen.
concs_ssa_1 = vcat(single[1:length(single)]...)[:]; expt_c = vcat(art_data...)[:];

fig, axs = PyPlot.subplots(2, 1, sharex = true, tight_layout = true);
axs[2].set_xlabel(L"t"); axs[1].set_ylabel(L"c_{exp}(t)"); axs[2].set_ylabel(L"c_{SSA}(t)"); 
axs[1].plot(range(1,length(expt_c),step=1),expt_c); axs[2].plot(range(1,length(concs_ssa_1),step=1),concs_ssa_1);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
#   0.002380 seconds (6.37 k allocations: 665.266 KiB)

# %%
fig, ax = PyPlot.subplots(1, 2, sharey = true);
true_bin_vals_inf, other_stuff = ax[1].hist(concs_ssa_1[:], bins = mod_bins, density = true);
ax[1].set_title("inferred params"); 
true_bin_vals, other_stuff = ax[2].hist(expt_c[:], bins = mod_bins, density = true);
ax[2].set_title("real params");
print("Hellinger distance between these is: ", hellinger(true_bin_vals_inf[:],true_bin_vals[:])) # print the bin values.
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# Hellinger distance between these is: 0.11540830846797472

# %% [markdown]
# # Run them again!

# %%
n_particles = 1000;
#threshold_schedule = [2.5, 1.25, 0.75, 0.5, 0.4, 0.3, 0.25, 0.2, 0.15, 0.12];
threshold_schedule = [8.0, 6.0, 5.0, 4.0, 3.5, 3.0, 2.8];

priors = [Uniform(-0.5, 0.5), Uniform(0.0, 1.3), Uniform(0.0, 1.0),
          Uniform(0.0, 1.3)];

sim_abcsmc_res_conc_2 = SimulatedABCSMC(art_data,
    simulator_function_conc,
    priors,
    threshold_schedule,
    n_particles;
    write_progress=true,
    distance_function = new_distance,
    max_iter = convert(Int,1E5))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053","#E75935","#E84D26","#E84117","#CF3008","#AB2402","#351D17"]
plot(sim_abcsmc_res_conc_2, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 8.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC rejection simulation. Accepted 637/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC SMC simulation ϵ = 6.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 381/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 747/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 5.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 254/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 528/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 787/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 4.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 165/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 320/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 485/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 648/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 799/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 965/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 3.5
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 114/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 244/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 361/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 490/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 600/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 709/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 847/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 991/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 3.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 24/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 59/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 83/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 117/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 146/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 175/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 202/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 233/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 256/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 291/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 314/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 341/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 363/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 393/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 429/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 451/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 483/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 505/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 534/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 565/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 596/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 623/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 657/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 691/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 713/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 748/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 781/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 809/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 833/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 865/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 897/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 919/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 949/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 973/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 2.8
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 12/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 25/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 39/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 46/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 51/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 66/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 75/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 88/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 100/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 114/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 128/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 141/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 155/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 169/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 179/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 186/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 202/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 209/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 225/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 233/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 244/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 252/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 267/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 282/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 296/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 318/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 333/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 348/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 355/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 370/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 379/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 387/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 397/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 405/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 418/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 428/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 434/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 442/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 454/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 465/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 479/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 489/42000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 507/43000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 517/44000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 530/45000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 540/46000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 545/47000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 554/48000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 568/49000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 584/50000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 590/51000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 606/52000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 620/53000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 627/54000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 640/55000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 651/56000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 658/57000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 672/58000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 680/59000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 693/60000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 705/61000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 714/62000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 727/63000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 735/64000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 748/65000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 760/66000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 769/67000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 787/68000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 795/69000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 810/70000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 823/71000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 840/72000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 855/73000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 868/74000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 877/75000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 884/76000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 894/77000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 908/78000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 919/79000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 933/80000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 938/81000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 948/82000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 966/83000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 979/84000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 990/85000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238

# %%
pars_conc_2 = [median(sim_abcsmc_res_conc_2.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#  0.26014026720659267
#  0.5070278440936353
#  0.3693986567011939
#  0.18871986309620298

# %%
true_par
# Out:
# 4-element Array{Float64,1}:
#  0.025
#  1.0
#  0.5
#  1.0e-6

# %%
single = @time Single_lin(num_sep_all_lins[1], pars_conc_2, v0_n0_th[1]); # do for first gen.
concs_ssa_1 = vcat(single[1:length(single)]...)[:]; expt_c = vcat(art_data...)[:];

fig, axs = PyPlot.subplots(2, 1, sharex = true, tight_layout = true);
axs[2].set_xlabel(L"t"); axs[1].set_ylabel(L"c_{exp}(t)"); axs[2].set_ylabel(L"c_{SSA}(t)"); 
axs[1].plot(range(1,length(expt_c),step=1),expt_c); axs[2].plot(range(1,length(concs_ssa_1),step=1),concs_ssa_1);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
#   0.002669 seconds (7.34 k allocations: 756.297 KiB)

# %%
fig, ax = PyPlot.subplots(1, 2, sharey = true);
true_bin_vals_inf, other_stuff = ax[1].hist(concs_ssa_1[:], bins = mod_bins, density = true);
ax[1].set_title("inferred params"); 
true_bin_vals, other_stuff = ax[2].hist(expt_c[:], bins = mod_bins, density = true);
ax[2].set_title("real params");
print("Hellinger distance between these is: ", hellinger(true_bin_vals_inf[:],true_bin_vals[:])) # print the bin values.
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# Hellinger distance between these is: 0.11124467932187886

# %%
n_particles = 1000;
#threshold_schedule = [2.5, 1.25, 0.75, 0.5, 0.4, 0.3, 0.25, 0.2, 0.15, 0.12];
threshold_schedule = [8.0, 6.0, 5.0, 4.0, 3.5, 3.0, 2.8];

priors = [Uniform(-0.5, 0.5), Uniform(0.0, 1.3), Uniform(0.0, 1.0),
          Uniform(0.0, 1.3)];

sim_abcsmc_res_conc_3 = SimulatedABCSMC(art_data,
    simulator_function_conc,
    priors,
    threshold_schedule,
    n_particles;
    write_progress=true,
    distance_function = new_distance,
    max_iter = convert(Int,1E5))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053","#E75935"]#,"#E84D26","#E84117","#CF3008","#AB2402","#351D17"]
plot(sim_abcsmc_res_conc_3, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 8.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC rejection simulation. Accepted 633/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC SMC simulation ϵ = 6.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 403/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 761/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 5.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 270/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 527/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 784/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 4.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 60/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 129/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 189/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 252/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 324/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 394/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 447/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 512/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 578/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 639/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 704/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 773/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 830/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 885/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 940/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 3.5
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 44/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 89/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 135/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 179/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 228/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 278/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 313/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 364/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 413/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 453/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 501/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 545/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 595/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 627/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 671/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 710/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 748/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 792/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 822/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 872/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 912/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 958/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 996/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 3.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 18/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 35/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 51/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 67/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 78/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 95/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 114/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 127/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 141/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 159/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 170/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 187/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 203/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 219/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 246/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 259/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 275/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 299/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 321/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 338/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 354/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 367/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 380/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 393/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 408/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 428/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 442/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 459/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 476/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 500/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 515/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 539/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 558/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 574/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 591/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 613/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 630/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 649/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 666/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 683/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 697/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 707/42000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 722/43000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 740/44000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 762/45000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 775/46000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 789/47000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 800/48000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 820/49000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 836/50000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 858/51000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 879/52000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 891/53000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 907/54000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 926/55000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 945/56000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 959/57000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 972/58000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 992/59000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 2.8
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 3/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 7/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 9/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 16/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 18/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 22/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 28/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 28/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 32/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 37/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 41/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 43/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 49/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 50/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 52/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 54/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 56/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 62/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 66/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 73/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 75/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 78/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 83/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 87/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 90/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 94/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 100/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 106/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 108/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 114/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 115/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 121/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 126/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 129/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 131/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 134/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 141/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 143/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 148/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 152/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 159/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 163/42000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 166/43000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 169/44000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 171/45000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 176/46000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 182/47000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 184/48000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 188/49000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 191/50000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 194/51000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 195/52000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 200/53000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 203/54000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 206/55000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 211/56000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 215/57000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 219/58000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 221/59000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 226/60000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 234/61000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 240/62000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 245/63000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 249/64000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 254/65000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 262/66000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 267/67000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 273/68000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 275/69000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 278/70000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 279/71000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 283/72000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 288/73000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 292/74000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 294/75000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 299/76000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 301/77000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 307/78000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 308/79000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 311/80000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 315/81000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 318/82000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 321/83000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 324/84000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 328/85000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 330/86000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 334/87000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 338/88000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 340/89000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 346/90000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 350/91000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 355/92000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 357/93000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 362/94000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 363/95000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 369/96000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 373/97000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 375/98000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 378/99000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 381/100000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Warning: Simulation reached maximum 100000 iterations before finding 1000 particles - will return 381
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:248

# %%
pars_conc_3 = [median(sim_abcsmc_res_conc_3.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#  0.09669531906127728
#  0.6319770873480753
#  0.3940352328262167
#  0.3816452994374113

# %%
true_par
# Out:
# 4-element Array{Float64,1}:
#  0.025
#  1.0
#  0.5
#  1.0e-6

# %%
single = @time Single_lin(num_sep_all_lins[1], pars_conc_3, v0_n0_th[1]); # do for first gen.
concs_ssa_1 = vcat(single[1:length(single)]...)[:]; expt_c = vcat(art_data...)[:];

fig, axs = PyPlot.subplots(2, 1, sharex = true, tight_layout = true);
axs[2].set_xlabel(L"t"); axs[1].set_ylabel(L"c_{exp}(t)"); axs[2].set_ylabel(L"c_{SSA}(t)"); 
axs[1].plot(range(1,length(expt_c),step=1),expt_c); axs[2].plot(range(1,length(concs_ssa_1),step=1),concs_ssa_1);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
#   0.001991 seconds (6.04 k allocations: 634.047 KiB)

# %%
fig, ax = PyPlot.subplots(1, 2, sharey = true);
true_bin_vals_inf, other_stuff = ax[1].hist(concs_ssa_1[:], bins = mod_bins, density = true);
ax[1].set_title("inferred params"); 
true_bin_vals, other_stuff = ax[2].hist(expt_c[:], bins = mod_bins, density = true);
ax[2].set_title("real params");
print("Hellinger distance between these is: ", hellinger(true_bin_vals_inf[:],true_bin_vals[:])) # print the bin values.
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# Hellinger distance between these is: 0.10249545645772905

# %% [markdown]
# ## Burst size volume dependence

# %% [markdown]
# Set-up the artificial SSA trajectory.

# %%
true_par_2 = [0.025, 1E-6, 0.5, 1.0];

# %%
art_data_2 = simulator_function_conc(true_par_2);

# %%
sum([new_distance(vcat(simulator_function_conc(true_par_2)...),vcat(simulator_function_conc(true_par_2)...)) for i in 1:1000])/1000
# Out:
# 3.19416856536747

# %%
n_particles = 1000;
#threshold_schedule_b = [2.5, 1.25, 0.75, 0.5, 0.4, 0.3, 0.215];
threshold_schedule_b = [8.0, 6.0, 5.0, 4.0, 3.5, 3.1];

priors = [Uniform(-0.5, 0.5), Uniform(0.0, 1.3), Uniform(0.0, 1.0),
          Uniform(0.0, 1.3)];

sim_abcsmc_res_conc_1b = SimulatedABCSMC(art_data_2,
    simulator_function_conc,
    priors,
    threshold_schedule_b,
    n_particles;
    write_progress=true,
    distance_function = new_distance,
    max_iter = convert(Int,1E5))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053","#E75935","#E84D26","#E84117","#CF3008","#AB2402","#351D17"]
plot(sim_abcsmc_res_conc_1b, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 8.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC rejection simulation. Accepted 685/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC SMC simulation ϵ = 6.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 427/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 852/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 5.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 337/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 697/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 4.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 197/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 389/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 610/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 809/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 3.5
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 134/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 263/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 383/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 521/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 648/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 792/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 944/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 3.1
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 42/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 89/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 156/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 203/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 262/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 307/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 338/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 379/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 415/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 457/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 498/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 557/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 598/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 644/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 687/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 730/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 788/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 830/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 875/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 915/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 958/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 999/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238

# %%
pars_conc_1b = [median(sim_abcsmc_res_conc_1b.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#  0.10661933607602511
#  0.5577053995886646
#  0.37546906099951716
#  0.4771543153787624

# %%
true_par_2
# Out:
# 4-element Array{Float64,1}:
#  0.025
#  1.0e-6
#  0.5
#  1.0

# %%
single = @time Single_lin(num_sep_all_lins[1], pars_conc_1b, v0_n0_th[1]); # do for first gen.
concs_ssa_1 = vcat(single[1:length(single)]...)[:]; expt_c = vcat(art_data_2...)[:];

fig, axs = PyPlot.subplots(2, 1, sharex = true, tight_layout = true);
axs[2].set_xlabel(L"t"); axs[1].set_ylabel(L"c_{exp}(t)"); axs[2].set_ylabel(L"c_{SSA}(t)"); 
axs[1].plot(range(1,length(expt_c),step=1),expt_c); axs[2].plot(range(1,length(concs_ssa_1),step=1),concs_ssa_1);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
#   0.002054 seconds (5.63 k allocations: 595.609 KiB)

# %%
fig, ax = PyPlot.subplots(1, 2, sharey = true);
true_bin_vals_inf, other_stuff = ax[1].hist(concs_ssa_1[:], bins = mod_bins, density = true);
ax[1].set_title("inferred params"); 
true_bin_vals, other_stuff = ax[2].hist(expt_c[:], bins = mod_bins, density = true);
ax[2].set_title("real params");
print("Hellinger distance between these is: ", hellinger(true_bin_vals_inf[:],true_bin_vals[:])) # print the bin values.
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# Hellinger distance between these is: 0.11202077792148045

# %% [markdown]
# # Run them again!

# %%
n_particles = 1000;
#threshold_schedule_b = [2.5, 1.25, 0.75, 0.5, 0.4, 0.3, 0.215];
threshold_schedule_b = [8.0, 6.0, 5.0, 4.0, 3.5, 3.1];

priors = [Uniform(-0.5, 0.5), Uniform(0.0, 1.3), Uniform(0.0, 1.0),
          Uniform(0.0, 1.3)];

sim_abcsmc_res_conc_2b = SimulatedABCSMC(art_data_2,
    simulator_function_conc,
    priors,
    threshold_schedule_b,
    n_particles;
    write_progress=true,
    distance_function = new_distance,
    max_iter = convert(Int,1E5))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053","#E75935","#E84D26","#E84117","#CF3008","#AB2402","#351D17"]
plot(sim_abcsmc_res_conc_2b, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 8.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC rejection simulation. Accepted 689/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC SMC simulation ϵ = 6.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 386/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 800/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 5.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 314/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 680/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 4.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 149/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 323/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 501/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 673/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 850/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 3.5
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 83/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 148/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 234/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 301/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 377/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 456/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 523/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 599/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 662/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 729/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 796/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 875/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 955/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 3.1
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 33/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 65/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 106/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 136/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 162/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 199/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 235/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 275/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 313/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 347/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 384/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 412/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 450/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 484/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 526/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 560/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 596/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 630/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 665/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 694/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 728/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 768/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 805/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 833/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 867/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 902/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 942/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 982/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238

# %%
pars_conc_2b = [median(sim_abcsmc_res_conc_2b.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#  -0.10663575983225942
#   0.8843374585349915
#   0.4560645961328331
#   0.4643700074257751

# %%
true_par_2
# Out:
# 4-element Array{Float64,1}:
#  0.025
#  1.0e-6
#  0.5
#  1.0

# %%
single = @time Single_lin(num_sep_all_lins[1], pars_conc_2b, v0_n0_th[1]); # do for first gen.
concs_ssa_1 = vcat(single[1:length(single)]...)[:]; expt_c = vcat(art_data_2...)[:];

fig, axs = PyPlot.subplots(2, 1, sharex = true, tight_layout = true);
axs[2].set_xlabel(L"t"); axs[1].set_ylabel(L"c_{exp}(t)"); axs[2].set_ylabel(L"c_{SSA}(t)"); 
axs[1].plot(range(1,length(expt_c),step=1),expt_c); axs[2].plot(range(1,length(concs_ssa_1),step=1),concs_ssa_1);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
#   0.001843 seconds (5.09 k allocations: 545.359 KiB)

# %%
fig, ax = PyPlot.subplots(1, 2, sharey = true);
true_bin_vals_inf, other_stuff = ax[1].hist(concs_ssa_1[:], bins = mod_bins, density = true);
ax[1].set_title("inferred params"); 
true_bin_vals, other_stuff = ax[2].hist(expt_c[:], bins = mod_bins, density = true);
ax[2].set_title("real params");
print("Hellinger distance between these is: ", hellinger(true_bin_vals_inf[:],true_bin_vals[:])) # print the bin values.
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
# Hellinger distance between these is: 0.10915561337332473

# %%
n_particles = 1000;
#threshold_schedule_b = [2.5, 1.25, 0.75, 0.5, 0.4, 0.3, 0.215];
threshold_schedule_b = [8.0, 6.0, 5.0, 4.0, 3.5, 3.1];

priors = [Uniform(-0.5, 0.5), Uniform(0.0, 1.3), Uniform(0.0, 1.0),
          Uniform(0.0, 1.3)];

sim_abcsmc_res_conc_3b = SimulatedABCSMC(art_data_2,
    simulator_function_conc,
    priors,
    threshold_schedule_b,
    n_particles;
    write_progress=true,
    distance_function = new_distance,
    max_iter = convert(Int,1E5))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053","#E75935"]#,"#E84D26","#E84117","#CF3008","#AB2402","#351D17"]
plot(sim_abcsmc_res_conc_3b, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 8.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC rejection simulation. Accepted 678/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC SMC simulation ϵ = 6.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 430/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 851/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 5.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 349/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 688/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 4.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 194/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 376/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 575/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 780/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 3.5
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 114/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 219/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 314/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 419/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 527/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 632/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 737/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 834/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 928/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 3.1
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 30/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 77/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 112/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 151/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 197/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 240/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 283/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 322/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 374/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 421/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 449/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 480/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 521/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 568/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 602/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 640/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 681/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 726/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 773/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 816/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 850/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 898/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 929/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 969/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238

# %%
pars_conc_3b = [median(sim_abcsmc_res_conc_3b.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#  -0.18913825158430353
#   0.9805889223676487
#   0.4524502841494202
#   0.53769571899951

# %%
true_par_2
# Out:
# 4-element Array{Float64,1}:
#  0.025
#  1.0e-6
#  0.5
#  1.0
