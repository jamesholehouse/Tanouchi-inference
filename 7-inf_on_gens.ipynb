# %% [markdown]
# # (7) Inference done per generation

# %% [markdown]
# In this notebook we use the SMC-ABC inference on the generations individually in order to test if this provides a better inference of artificial parameters not seen when inference is performed on the entire lineage all at once.
#
# Let's start by importing the SSA and the experimental data (only to be used to given initial volumes, molecule numbers and exponential growth rates) and processing it as was done in notebook 5:

# %%
include("./SSA_file.jl"); using .SSAmod;
include("./extract_gens.jl"); using .extract;
using DelimitedFiles;

# %%
filelist = readdir("Analysis_MC4100_37C/MC4100_37C/"); # take the file names - each file is for a different lineage.
raw_data = []; # define the raw data array.
for (i,file) in enumerate(sort!(filelist))
    push!(raw_data,readdlm(string("Analysis_MC4100_37C/MC4100_37C/", file), ',', Float64, '\n'))
end

# %%
fluor_all_lins = [raw_data[x][:,4] for x in 1:length(raw_data)]; # non-separated fluor data.
vol_all_lins = [raw_data[x][:,3] for x in 1:length(raw_data)]; # non-separated vol data.

fluor_sep_all_lins = extract_gens(raw_data,4); # the fluor. data for each lineage sep into gens.
vol_sep_all_lins = extract_gens(raw_data,3); # the vol. data for each lineage sep into gens.
times_sep_all_lins = extract_gens(raw_data,1); # the time pt data for each lineage sep into gens.

props = vec(readdlm("MN_props.csv", ',', Float64, '\n'));
exp_grs = readdlm("exp_grs_all.csv", ',', Float64, '\n');

num_sep_all_lins = []; # sep into gens.
for i in 1:length(fluor_sep_all_lins)
    push!(num_sep_all_lins,fluor_sep_all_lins[i]./props[i])
end

# un-sep molecule number and concs for each lineage (including 70th gen to be removed) later).
num_all_lins = [fluor_all_lins[x]./props[x] for x in 1:length(fluor_all_lins)];
conc_all_lins = [num_all_lins[x]./vol_all_lins[x] for x in 1:length(fluor_all_lins)];

v0_n0_th = []; # 2-d array to storing (1) the initial values of vol (2) molecule #  and (3) theta for each gen in each lin
for x in 1:length(fluor_all_lins) # the lin loop
    v0_n0_th_x = [];
    for y in 1:length(fluor_sep_all_lins[x]) # the gen loop 1 --> 69
        num = fluor_sep_all_lins[x][y][1]/props[x]
        push!(v0_n0_th_x, [vol_sep_all_lins[x][y][1], num, exp_grs[x,y]])
    end
    push!(v0_n0_th, v0_n0_th_x)
end

# %% [markdown]
# ## First attempt at inference from artificial data

# %% [markdown]
# Now let's create the experimental data of which we wish to infer the parameters of. We again introduce the lineage function created in notebook 5. We set $\log_{10}(\alpha_0) = 0.5$, $\alpha_1 = 1.0$, $\log_{10}(\beta_0) = -1.8$ and $\beta_1 = 0.3$:

# %%
true_par = [0.0, 1.0, -1.0, 0.1];

# %% [markdown]
# We take the initial conditions on molecule numbers and volume from generation 1 in lineage 1 of the Tanouchi data, as well as the fluorescence per molecule and exponenital growth rate in each generation.

# %%
gen_data = num_sep_all_lins[1][1]; # take the data for first gen in the first lineage, this gives the data form for Single_lin.
lin_ic = v0_n0_th[1][1]; # pre-set params for gen 1 lineage 1.

expt_ssa_conc = SSA_deg_zero_log(1, true_par, lin_ic, length(gen_data))[2]
# Out:
# 1×33 Array{Float64,2}:
#  3.82805  3.73213  3.63861  3.54743  …  4.11824  4.01505  4.13157  4.02804

# %% [markdown]
# Let's plot this data:

# %%
using LaTeXStrings, Plots, Statistics; pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
PyPlot.plot(range(1,length(expt_ssa_conc),step=1),expt_ssa_conc[:]);
PyPlot.ylabel(L"c_{true}(t)"); PyPlot.xlabel(L"t"); PyPlot.xlim([1,length(expt_ssa_conc)]);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Get an estimate of the sample error for the minimum threshold.

# %%
# sim is the number of sims to average over.
function Single_gen_mean(sim::Int64, gen_data, inf_par, ics) # arguments are wrt each lineage.
    ssa = SSA_deg_zero_log(sim, inf_par, ics[1], length(gen_data[1])-1); # for each gen run the SSA with correct ics.
    SSA_n = mean(ssa[1],dims=1); SSA_c = mean(ssa[2],dims=1); SSA_v = mean(ssa[3],dims=1);
    return SSA_n, SSA_c, SSA_v # return in the same order as the SSA.
end
# Out:
# Single_gen_mean (generic function with 1 method)

# %%
many = @time Single_gen_mean(1000, num_sep_all_lins[1],[0.5, 1.0, -1.8, 0.3], v0_n0_th[1]) # do for first gen.
# Out:
#   0.090163 seconds (340.18 k allocations: 31.395 MiB)
# ([8.027727183295726 8.153727183295725 … 14.72572718329573 15.07672718329573], [3.828050042580989 3.7907050638857185 … 3.2796407844391795 3.2736739463352613], [2.0970800000000023 2.1509790516220293 … 4.49004270625139 4.605445572908532])

# %% [markdown]
# Plot the single experimental trajectory against the mean trajectory.

# %%
m_concs = many[2][:];

fig, axs = PyPlot.subplots(2, 1, sharex = true, tight_layout = true);
axs[2].set_xlabel(L"t"); axs[1].set_ylabel(L"n_{M}(t)"); axs[2].set_ylabel(L"n_{SSA}(t)"); 
axs[1].plot(range(0,length(m_concs)-1,step=1),m_concs); axs[2].plot(range(0,length(expt_ssa_conc[:])-1,step=1),expt_ssa_conc[:]);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %% [markdown]
# Calculate the sampling threshold distance.

# %%
thres_dist_conc = sqrt(sum((expt_ssa_conc .- m_concs).*(expt_ssa_conc .- m_concs)))
# Out:
# 21.57145667868984

# %% [markdown]
# A bit of experimentation gives a good threshold of around 15.

# %% [markdown]
# Now let's set up the tools needed to perform the inference of the parameters as we did in notebook 5.

# %%
# function that returns the SSA concentration for lineage specified abvove.
function simulator_function_conc(var_params)
    gen_conc = SSA_deg_zero_log(1, var_params, v0_n0_th[1][1], length(num_sep_all_lins[1][1]))[2];
    return gen_conc
end
# Out:
# simulator_function_conc (generic function with 1 method)

# %%
simulator_function_conc(true_par)
# Out:
# 1×33 Array{Float64,2}:
#  3.82805  3.73213  3.63861  3.98933  …  4.34668  4.23776  4.13157  4.02804

# %%
using GpABC, LambertW, Distances, Plots, Distributions; pyplot()
# Out:
# Plots.PyPlotBackend()

# %% [markdown]
# Start the inference:
# - (1) `n_particles` gives the number of accepted ABC parameter sets for each step in the threshold simulator.
# - (2) `threshold_schedule` gives the different thresholds for the SMC-ABC inference.
# - (3) `reference_data_c` is the concentration data for the first 69 generations in lineage 1.
# - (4) `priors` is the array containing the priors on each inferred parameter (chosen to be uniform).

# %%
n_particles = 500;
threshold_schedule = [100.0, 50.0, 40.0, 30.0, 27.5, 26.0];

priors = [Uniform(-2, 2.0), Uniform(0.0, 2.5), Uniform(-2, 2.0),
          Uniform(0.0, 2.5)];

sim_abcsmc_res_conc_1 = SimulatedABCSMC(expt_ssa_conc,
    simulator_function_conc,
    priors,
    threshold_schedule,
    n_particles;
    write_progress=true,
    max_iter = convert(Int,15E4))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67"]#,"#E57053","#E75935","#E84D26","#E84117"]#,"#CF3008","#AB2402"]#,"#351D17"]
plot(sim_abcsmc_res_conc_1, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 100.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC rejection simulation. Accepted 365/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:87
# ┌ Info: GpABC SMC simulation ϵ = 50.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 40.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 30.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 27.5
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 26.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 441/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238

# %% [markdown]
# Print the median inferred parameters.

# %%
pars_conc_1 = [median(sim_abcsmc_res_conc_1.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#   0.1899981371450799
#   0.881214955973815
#  -1.5589495025208553
#   0.6109057984046267

# %% [markdown]
# Print the differences.

# %%
diff = (pars_conc_1 - true_par)
# Out:
# 4-element Array{Float64,1}:
#   0.1899981371450799
#  -0.11878504402618495
#  -0.5589495025208553
#   0.5109057984046267

# %% [markdown]
# Plot an SSA trajectory using the inferred parameters and compare against the experimental SSA.

# %%
single = @time simulator_function_conc(pars_conc_1)[:]; # do for first gen.
concs_ssa_1 = single; expt_c = expt_ssa_conc[:];

fig, axs = PyPlot.subplots(2, 1, sharex = true, tight_layout = true);
axs[2].set_xlabel(L"t"); axs[1].set_ylabel(L"c_{exp}(t)"); axs[2].set_ylabel(L"c_{SSA}(t)"); 
axs[1].plot(range(1,length(expt_c),step=1),expt_c); axs[2].plot(range(1,length(concs_ssa_1),step=1),concs_ssa_1);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
#   0.000050 seconds (141 allocations: 14.281 KiB)

# %% [markdown]
# ## Second inference from artificial data

# %% [markdown]
# Now let's create the experimental data of which we wish to infer the parameters of. We again introduce the lineage function created in notebook 5. We set $\log_{10}(\alpha_0) = 0.5$, $\alpha_1 = 1.0$, $\log_{10}(\beta_0) = -1.8$ and $\beta_1 = 0$:

# %%
true_par_2 = [0.5, 1.0, -1.8, 0.0];

# %% [markdown]
# Question: can we infer $\beta_1 = 0$ without performing inference of $\beta_1$ in log scale? We take the initial conditions on molecule numbers and volume from lineage 1 of the Tanouchi data, as well as the fluorescence per molecule and exponenital growth rate in each generation.

# %%
expt_ssa_conc_2 = Single_lin(num_sep_all_lins[1], true_par_2, v0_n0_th[1])[2];

# %% [markdown]
# Let's plot this data:

# %%
PyPlot.plot(range(1,length(expt_ssa_conc_2),step=1),expt_ssa_conc_2[:]);
PyPlot.ylabel(L"c_{true}(t)"); PyPlot.xlabel(L"t"); PyPlot.xlim([1,length(expt_ssa_conc_2)]);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
n_particles = 500;
threshold_schedule = [1000.0, 500.0, 250.0, 125.0, 100.0, 75.0, 50.0, 40.0, 35.0, 33.75, 32.5, 31.25, 30.0]#, 29.0, 28.0, 27.5];

priors = [Uniform(-4.0, 2.0), Uniform(0.0, 2.5), Uniform(-4.0, 1.5),
          Uniform(0.0, 2.5)];

sim_abcsmc_res_conc_2 = SimulatedABCSMC(expt_ssa_conc_2,
    simulator_function_conc,
    priors,
    threshold_schedule,
    n_particles;
    write_progress=true,
    max_iter = convert(Int,15E4))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053","#E75935","#E84D26","#E84117","#CF3008","#AB2402"]#,"#351D17"]
plot(sim_abcsmc_res_conc_2, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 1000.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 500.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 250.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 125.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 100.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 75.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 50.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 40.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation ϵ = 35.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 70/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 166/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 261/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 353/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 457/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 33.75
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 115/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 224/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 339/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 463/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 32.5
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 143/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 290/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 446/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 31.25
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 163/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 308/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 431/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 30.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 100/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 179/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 252/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 329/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 398/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 471/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238

# %% [markdown]
# Print the inferred median parameters.

# %%
pars_conc_2 = [median(sim_abcsmc_res_conc_2.population[end][:,i]) for i in 1:4]
# Out:
# 4-element Array{Float64,1}:
#   0.07322915034624952
#   1.6147191287535598
#  -2.4281898910005917
#   1.2496336934397934

# %% [markdown]
# Print the differences.

# %%
diff_2 = (pars_conc_2 - true_par_2)
# Out:
# 4-element Array{Float64,1}:
#  -0.42677084965375045
#   0.6147191287535598
#  -0.6281898910005916
#   1.2496336934397934

# %% [markdown]
# Plot an SSA trajectory using the inferred parameters and compare against the experimental SSA.

# %%
single_2 = @time Single_lin(num_sep_all_lins[1], pars_conc_2, v0_n0_th[1]); # do for first gen.
concs_ssa_2 = single_2[2][1:length(single_2[2])]; expt_c_2 = expt_ssa_conc_2[:];

fig, axs = PyPlot.subplots(2, 1, sharex = true, tight_layout = true);
axs[2].set_xlabel(L"t"); axs[1].set_ylabel(L"c_{exp}(t)"); axs[2].set_ylabel(L"c_{SSA}(t)"); 
axs[1].plot(range(1,length(expt_c_2),step=1),expt_c_2); axs[2].plot(range(1,length(concs_ssa_2),step=1),concs_ssa_2);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
#   0.006760 seconds (27.71 k allocations: 2.069 MiB)

# %% [markdown]
# ## Let's try inferring all the params in log-space

# %% [markdown]
# Now let's create the experimental data of which we wish to infer the parameters of. We again introduce the lineage function created in notebook 5. We set $\ln(\alpha_0) = -0.1$, $\ln(\alpha_1) = -0.2$, $\ln(\beta_0) = -2.0$ and $\ln(\beta_1) = -3.0$:

# %%
true_par_log = [-0.1, -0.2, -2.0, -3.0];

# %% [markdown]
# Question: can we infer $\beta_1 = 0$ without performing inference of $\beta_1$ in log scale? We take the initial conditions on molecule numbers and volume from lineage 1 of the Tanouchi data, as well as the fluorescence per molecule and exponenital growth rate in each generation.

# %%
lineage_data = num_sep_all_lins[1]; # take the data for the first lineage, this gives the data form for Single_lin.
lin_ic = v0_n0_th[1]; # pre-set params for lineage 1.

function Single_lin_log(lin_data, inf_par, ics) # arguments are wrt each lineage.
    SSA_data_n = [];
    SSA_data_c = [];
    SSA_data_v = [];
    for (i,gen) in enumerate(lin_data)
        ssa = SSA_deg_zero_all_log(1, inf_par, ics[i], length(gen)); # for each gen run the SSA with correct ics.
        append!(SSA_data_n, ssa[1]); append!(SSA_data_c, ssa[2]); append!(SSA_data_v, ssa[3]);
    end
    return convert(Array{Float64,2},transpose(SSA_data_n)), convert(Array{Float64,2},transpose(SSA_data_c)), SSA_data_v # return in the same order as the SSA.
end
# Out:
# Single_lin_log (generic function with 1 method)

# %%
# function that returns the SSA concentration for lineage specified abvove.
function simulator_function_conc_log(var_params)
    lin_conc = Single_lin_log(lineage_data, var_params, lin_ic)[2]
    return lin_conc
end
# Out:
# simulator_function_conc_log (generic function with 1 method)

# %%
expt_ssa_conc_log = Single_lin_log(num_sep_all_lins[1], true_par_log, v0_n0_th[1])[2];

# %% [markdown]
# Let's plot this data:

# %%
PyPlot.plot(range(1,length(expt_ssa_conc_log),step=1),expt_ssa_conc_log[:]);
PyPlot.ylabel(L"c_{true}(t)"); PyPlot.xlabel(L"t"); PyPlot.xlim([1,length(expt_ssa_conc_log)]);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# Difficulty with inferring in the log space is that the inference parameters are much more sensitive to perturbation, hence zooming in on the minimum of the objective function can be quite difficult. Hence we must carefully choose our thresholds.

# %%
n_particles = 200;
threshold_schedule = [75.0, 60.0, 50.0, 47.5, 45.0, 44.0, 43.0]#, 41.25, 40.5, 40.0]#, 35.0, 33.75, 32.5, 31.25, 30.0]#, 29.0, 28.0, 27.5];

priors = [Uniform(-2.0*log(10), log(10)), Uniform(-log(10), log(3.0)), 
                Uniform(-2.0*log(10), log(10)), Uniform(-log(10), log(3.0))];

sim_abcsmc_res_conc_log = SimulatedABCSMC(expt_ssa_conc_log,
    simulator_function_conc_log,
    priors,
    threshold_schedule,
    n_particles;
    write_progress=true,
    max_iter = convert(Int,15E4))

# plot the results.
population_colors=["#351D17", "#502C23", "#754134", "#935343", "#B86854","#DA7E67","#E57053"]#,"#E75935","#E84D26"]#,"#E84117","#CF3008","#AB2402"]#,"#351D17"]
plot(sim_abcsmc_res_conc_log, population_colors=population_colors)
# Out:
# ┌ Info: GpABC rejection simulation. ϵ = 75.0.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/rejection.jl:47
# ┌ Info: GpABC SMC simulation ϵ = 60.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 150/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 50.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 28/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 65/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 105/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 134/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 167/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 198/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 47.5
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 17/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 40/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 59/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 81/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 96/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 108/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 131/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 150/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 170/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 189/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 45.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 7/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 9/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 12/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 14/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 19/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 26/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 29/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 32/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 36/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 43/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 48/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 51/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 59/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 67/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 71/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 77/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 83/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 86/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 88/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 92/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 95/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 97/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 101/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 108/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 113/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 117/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 122/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 128/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 131/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 134/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 137/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 142/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 150/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 152/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 154/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 157/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 160/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 165/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 167/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 173/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 177/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 179/42000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 183/43000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 184/44000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 191/45000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 195/46000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 199/47000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 44.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 3/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 5/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 6/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 9/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 10/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 10/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 12/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 13/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 13/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 15/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 17/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 17/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 21/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 22/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 24/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 26/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 27/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 29/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 31/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 32/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 32/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 34/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 37/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 42/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 43/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 45/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 45/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 46/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 50/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 52/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 54/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 56/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 57/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 57/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 60/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 61/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 68/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 70/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 73/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 75/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 75/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 76/42000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 81/43000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 84/44000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 85/45000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 85/46000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 85/47000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 91/48000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 92/49000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 96/50000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 97/51000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 101/52000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 102/53000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 107/54000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 109/55000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 109/56000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 111/57000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 113/58000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 114/59000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 116/60000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 120/61000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 121/62000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 125/63000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 127/64000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 129/65000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 130/66000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 130/67000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 131/68000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 132/69000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 132/70000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 132/71000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 135/72000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 136/73000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 139/74000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 143/75000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 143/76000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 146/77000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 149/78000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 153/79000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 154/80000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 158/81000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 160/82000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 163/83000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 167/84000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 168/85000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 171/86000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 171/87000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 175/88000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 176/89000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 177/90000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 180/91000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 181/92000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 182/93000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 184/94000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 185/95000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 188/96000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 190/97000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 194/98000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 198/99000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation ϵ = 43.0
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:193
# ┌ Info: GpABC SMC simulation accepted 3/1000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 3/2000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 4/3000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 6/4000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 8/5000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 8/6000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 8/7000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 8/8000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 11/9000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 11/10000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 11/11000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 11/12000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 11/13000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 11/14000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 11/15000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 11/16000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 12/17000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 12/18000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 13/19000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 14/20000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 15/21000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 15/22000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 17/23000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 21/24000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 22/25000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 23/26000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 27/27000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 27/28000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 27/29000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 28/30000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 29/31000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 30/32000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 30/33000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 32/34000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 33/35000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 34/36000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 34/37000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 34/38000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 34/39000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 35/40000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 35/41000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 37/42000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 37/43000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 39/44000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 40/45000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 42/46000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 42/47000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 44/48000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 44/49000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 45/50000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 47/51000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 50/52000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 50/53000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 52/54000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 53/55000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 53/56000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 53/57000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 53/58000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 54/59000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 55/60000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 56/61000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 57/62000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 58/63000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 59/64000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 60/65000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 61/66000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 62/67000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 64/68000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 66/69000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 67/70000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 67/71000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 67/72000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 70/73000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 70/74000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 70/75000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 70/76000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 72/77000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 73/78000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 75/79000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 76/80000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 77/81000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 77/82000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 78/83000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 78/84000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 81/85000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 82/86000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 83/87000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 86/88000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 87/89000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 87/90000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 87/91000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 89/92000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 90/93000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 91/94000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 93/95000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 94/96000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 96/97000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 98/98000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 99/99000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 99/100000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 99/101000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 101/102000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 102/103000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 104/104000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 105/105000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 105/106000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 105/107000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 108/108000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 108/109000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 109/110000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 109/111000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 109/112000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 110/113000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 112/114000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 112/115000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 112/116000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 113/117000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 113/118000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 113/119000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 114/120000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 114/121000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 115/122000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 116/123000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 117/124000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 118/125000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 119/126000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 119/127000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 119/128000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 120/129000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 122/130000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 122/131000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 123/132000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 124/133000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 124/134000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 124/135000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 124/136000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 125/137000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 126/138000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 127/139000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 130/140000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 131/141000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 131/142000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 131/143000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 132/144000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 133/145000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 133/146000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 133/147000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 134/148000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 134/149000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Info: GpABC SMC simulation accepted 134/150000 particles.
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:238
# ┌ Warning: Simulation reached maximum 150000 iterations before finding 200 particles - will return 134
# └ @ GpABC /home/s1402978/.julia/packages/GpABC/cR3wm/src/abc/smc.jl:248

# %% [markdown]
# Print the inferred median parameters.

# %%
pars_conc_log = [median(sim_abcsmc_res_conc_log.population[1][:,i]) for i in 1:4]
# Out:
# UndefVarError: sim_abcsmc_res_conc_log not defined
#
# Stacktrace:
#  [1] (::var"#57#58")(::Int64) at ./none:0
#  [2] iterate at ./generator.jl:47 [inlined]
#  [3] collect(::Base.Generator{UnitRange{Int64},var"#57#58"}) at ./array.jl:686
#  [4] top-level scope at In[167]:1
#  [5] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
#  [6] execute_code(::String, ::String) at /home/s1402978/.julia/packages/IJulia/a1SNk/src/execute_request.jl:27
#  [7] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/s1402978/.julia/packages/IJulia/a1SNk/src/execute_request.jl:86
#  [8] #invokelatest#1 at ./essentials.jl:710 [inlined]
#  [9] invokelatest at ./essentials.jl:709 [inlined]
#  [10] eventloop(::ZMQ.Socket) at /home/s1402978/.julia/packages/IJulia/a1SNk/src/eventloop.jl:8
#  [11] (::IJulia.var"#15#18")() at ./task.jl:356

# %% [markdown]
# Print the differences.

# %%
diff_log = (pars_conc_log - true_par_log)
# Out:
# 4-element Array{Float64,1}:
#   0.990662935753691
#  -1.4418122547317918
#  -1.5388371535541854
#   2.5749614632839344

# %% [markdown]
# Plot an SSA trajectory using the inferred parameters and compare against the experimental SSA.

# %%
single_log = @time Single_lin(num_sep_all_lins[1], pars_conc_log, v0_n0_th[1]); # do for first gen.
concs_ssa_log = single_log[2][1:length(single_log[2])]; expt_c_log = expt_ssa_conc_log[:];

fig, axs = PyPlot.subplots(2, 1, sharex = true, tight_layout = true);
axs[2].set_xlabel(L"t"); axs[1].set_ylabel(L"c_{exp}(t)"); axs[2].set_ylabel(L"c_{SSA}(t)"); 
axs[1].plot(range(1,length(expt_c_log),step=1),expt_c_log); axs[2].plot(range(1,length(concs_ssa_log),step=1),concs_ssa_log);
# Out:
# PyPlot.Figure(PyObject <Figure size 640x480 with 2 Axes>)
#   0.001524 seconds (12.95 k allocations: 734.641 KiB)
